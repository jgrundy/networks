# %% [markdown]
# # NYU CUSP: Applied Data Science, Network Analysis module, session 1
# # Network visualization and basic analysis

# %%
#add necessary libraries
import networkx as nx #library supporting networks
import matplotlib.pyplot as plt #plotting
#make sure plots are embedded into the notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# first let's explore the data structure for the network provided by networkx

# %%
#create an empty undirected network
G=nx.Graph()
#add a node
G.add_node(1)
#add several nodes
G.add_nodes_from([2,3,4])
#we can add not only numbers but also text (or any other python object) as a node 
G.add_node('A')
#now add an edge
G.add_edge(1,2)
#and a set of edges
G.add_edges_from([(1,3),(1,4),(3,4),('A',3),('A',4)])

# %%
#now let's see what we've done
print(G.nodes())
print(G.edges())
# Out:
# ['A', 1, 2, 3, 4]
# [('A', 3), ('A', 4), (1, 2), (1, 3), (1, 4), (3, 4)]

# %%
np.random.seed(2015) #fix the origin of random generator - see below why
#now let's visualize, which turns out to be fairly simple with networkx
nx.draw(G,with_labels=True)

# %% [markdown]
# note that the locations are selected by random - this is why we fixed random generator to make sure appearance is always the same. But what if we have the locations of the nodes we want the python to stick to?

# %%
#set up the location for our nodes
pos={1:(50,50),2:(25,50),3:(75,75),4:(75,25),'A':(85,50)}
#visualize for fixed node locations
nx.draw(G,pos=pos,with_labels=True)

# %% [markdown]
# But networkx does not only allow to store and visualize the networks. It can also perform a lot of useful computations for us, including some network properties. Let's do node degrees for example

# %%
G.degree()
# Out:
# {1: 3, 2: 1, 3: 3, 4: 3, 'A': 2}

# %%
#let's now use node degrees as sizes of the nodes visualized
nx.draw(G,pos=pos,node_size=200*np.array(G.degree().values()),with_labels=True)

# %% [markdown]
# networkx can also handle directed networks as well

# %%
G2=nx.DiGraph() #create a directed graph
#add same edges as before; notice that when we add edges nodes are added automatically
G2.add_edges_from([(1,2),(1,3),(1,4),(3,4),('A',3),('A',4)])

# %%
#visualize the network showing directions
nx.draw(G2,pos=pos,with_labels=True,arrows=True)

# %%
#calculate incoming and outgoing degrees
print(G2.in_degree())
print(G2.out_degree())
# Out:
# {'A': 0, 1: 0, 2: 1, 3: 2, 4: 3}
# {'A': 2, 1: 3, 2: 0, 3: 1, 4: 0}

# %% [markdown]
# we can also handle a weighted network

# %%
G3=nx.DiGraph() #create a directed graph
#add same edges as before but with weights
G3.add_weighted_edges_from([(1,2,2),(1,3,2),(1,4,2),(3,4,1),('A',3,3),('A',4,3)])
#we can also add separate edges in the following way
G3.add_edge('A',1,weight=5)

# %%
#we can access all the edges outgoing from a node 'A' like
print(G3['A'])
#a specific edge like
print(G3['A'][1])
#and modify its properties like
G3['A'][1]['weight']=3
# Out:
# {1: {'weight': 5}, 3: {'weight': 3}, 4: {'weight': 3}}
# {'weight': 5}

# %%
#now let's extract all the edge weights into a list (in the same order as edges go)
w=[d['weight'] for (u,v,d) in G3.edges(data=True)]
print(w)
# Out:
# [3, 3, 3, 2, 2, 2, 1]

# %%
#and visualize the network using edge weights for the edge thikness
nx.draw(G3,pos=pos,with_labels=True,arrows=True,width=w,node_size=500)

# %%
import numpy as np
import pandas as pd

# %%
cities = pd.read_csv( 'https://serv.cusp.nyu.edu/files/ADS-2015/NetworkAnalysis/lab1/citiesTable.csv' , index_col=0 )
cities.head()
# Out:
#              country name most active airport  long. most active airport  \
# city name
# London     United Kingdom            Heathrow                     -0.103
# Chicago     United States  Chicago Ohare Intl                    -87.842
# Paris              France   Charles De Gaulle                      2.916
# Moscow             Russia          Domododevo                     38.510
# Shanghai            China              Pudong                    122.342
#
#            lat. most active airport  number of routes  \
# city name
# London                       51.795              1984
# Chicago                      42.631              1406
# Paris                        49.021              1254
# Moscow                       55.681              1179
# Shanghai                     31.238              1115
#
#            number incoming flights  number outcoming flights  \
# city name
# London                         993                       992
# Chicago                        705                       702
# Paris                          626                       629
# Moscow                         589                       591
# Shanghai                       560                       556
#
#            number incoming domestic flights  \
# city name
# London                                   57
# Chicago                                 526
# Paris                                    68
# Moscow                                  231
# Shanghai                                357
#
#            number outcoming domestic flights  \
# city name
# London                                    57
# Chicago                                  523
# Paris                                     68
# Moscow                                   231
# Shanghai                                 353
#
#            number incoming international flights  \
# city name
# London                                       936
# Chicago                                      179
# Paris                                        558
# Moscow                                       358
# Shanghai                                     203
#
#            number outcoming international flights  only domestic flights  \
# city name
# London                                        934                      0
# Chicago                                       178                      0
# Paris                                         560                      0
# Moscow                                        359                      0
# Shanghai                                      202                      0
#
#            average distance  max. distance
# city name
# London                 3228          11153
# Chicago                2328          12416
# Paris                  3367          11652
# Moscow                 2772          10054
# Shanghai               2235          12245

# %%
#create a network with city names as nodes
Flights=nx.Graph()
Flights.add_nodes_from(cities.index)

# %%
#create a dictionary of city locations
CityPos={}
for c in cities.index:
    CityPos[c]=(cities['long. most active airport'][c],cities['lat. most active airport'][c])

# %%
CityPos
# Out:
# {'Deauville': (0.25700000000000001, 49.608000000000004),
#  'Yibin': (104.90700000000001, 29.333000000000002),
#  'Lianyungang': (119.416, 34.915999999999997),
#  'Castlegar': (-117.38799999999999, 49.493000000000002),
#  'BRISTOL': (-82.012999999999991, 36.792000000000002),
#  'Toledo': (-83.680000000000007, 41.978000000000002),
#  'Norman Wells': (-126.664, 65.468999999999994),
#  'Dammam': (50.328999999999994, 26.785),
#  'Paamiut': (-49.438000000000002, 62.652999999999999),
#  'Livingstone': (26.370999999999999, -17.702999999999999),
#  'Lanai': (-156.91999999999999, 21.309000000000001),
#  'Mitu': (-69.72399999999999, 1.4219999999999999),
#  'Bar Harbor': (-67.936000000000007, 44.748999999999995),
#  'Niamey': (2.306, 13.802),
#  'Kittila': (25.410999999999998, 68.168000000000006),
#  'Edmonton': (-113.3, 53.516000000000005),
#  'Caen': (-0.084000000000000005, 49.288000000000004),
#  'Tan Tan': (-10.603, 28.745999999999999),
#  'Alamosa': (-105.77799999999999, 37.725000000000001),
#  'Waterloo': (-92.001000000000005, 42.928000000000004),
#  'Wunnumin Lake': (-88.816000000000003, 53.488999999999997),
#  'Gizan': (42.976000000000006, 17.500999999999998),
#  'Bora Bora': (-151.58600000000001, -16.074000000000002),
#  'Zhijiang': (110.166, 27.734999999999999),
#  'La Chorrera': (-72.361999999999995, -0.55600000000000005),
#  'Plattsburgh': (-73.11399999999999, 45.083999999999996),
#  'Wolf Point': (-105.292, 48.156999999999996),
#  'Redding': (-121.82299999999999, 40.847999999999999),
#  'Kearney': (-98.344999999999999, 41.211000000000006),
#  'Exeter': (-3.0239999999999996, 51.223999999999997),
#  'Uzhgorod': (22.438000000000002, 49.056999999999995),
#  'Loei': (102.20299999999999, 17.730999999999998),
#  'Arusha': (37.055, -2.9470000000000001),
#  'St-Augustin': (-58.431000000000004, 51.351999999999997),
#  'Trail': (-117.34899999999999, 49.091999999999999),
#  'Tepic': (-104.738, 21.699000000000002),
#  'Yuncheng': (111.655, 35.030000000000001),
#  'Westsound': (-122.92200000000001, 49.028999999999996),
#  'Jerez': (-5.4340000000000002, 37.241),
#  'Branson': (-92.667999999999992, 36.885999999999996),
#  'Windsor': (-82.926000000000002, 42.458999999999996),
#  'Takaroa': (-144.375, -14.093),
#  'Buckland': (-160.58199999999999, 66.63600000000001),
#  'Strasbourg': (8.0470000000000006, 48.896999999999998),
#  'Vunisea': (178.261, -18.430999999999997),
#  'Bejaja': (5.1160000000000005, 37.186),
#  'Lilabari': (94.162000000000006, 27.491999999999997),
#  'Hay River': (-115.63799999999999, 61.398999999999994),
#  'Curitiba': (-48.626999999999995, -25.215),
#  'Duesseldorf': (7.2770000000000001, 51.481999999999999),
#  'Lamap': (168.37099999999998, -16.09),
#  'Kunsan': (127.02600000000001, 36.506),
#  'Donetsk': (38.231999999999999, 48.122),
#  'Karup': (9.2070000000000007, 56.494999999999997),
#  'Linkoeping': (16.134, 58.676000000000002),
#  'Mineralnye Vody': (43.136000000000003, 44.375),
#  'Hailey': (-113.82700000000001, 43.840000000000003),
#  'Boise': (-115.705, 43.939999999999998),
#  'Rockland': (-68.498999999999995, 44.100000000000001),
#  'Kilimanjaro': (37.124000000000002, -3.0499999999999998),
#  'Altoona': (-77.867000000000004, 40.493000000000002),
#  'Hamilton': (175.553, -37.777999999999999),
#  'Tabriz': (46.391000000000005, 38.222999999999999),
#  'Chipata': (32.978000000000002, -13.264000000000001),
#  'La Fortuna/San Carlos': (-84.391000000000005, 10.795999999999999),
#  'Brunswick': (-81.111000000000004, 31.430999999999997),
#  'Jinzhou': (121.10299999999999, 41.168999999999997),
#  'Colorado Springs': (-104.50200000000001, 39.343000000000004),
#  'Ciudad Juarez': (-106.04799999999999, 32.060000000000002),
#  'Eindhoven': (5.6239999999999997, 51.75),
#  'Harrison': (-92.592000000000013, 36.435000000000002),
#  'King Cove': (-161.77700000000002, 55.193000000000005),
#  'Zhoushan': (122.60299999999999, 30.556999999999999),
#  'Geraldton': (-86.900000000000006, 50.296999999999997),
#  'Burbank': (-117.932, 34.334000000000003),
#  'Urgench': (61.068999999999996, 41.972999999999999),
#  'Stuttgart': (9.3689999999999998, 49.148999999999994),
#  'Kitakyushu': (131.05700000000002, 34.408999999999999),
#  'Liverpool': (-2.75, 53.556000000000004),
#  'Libreville': (9.6870000000000012, 0.76400000000000001),
#  'Sanandaj': (47.015000000000001, 35.408999999999999),
#  'Tivat': (19.204999999999998, 42.673999999999999),
#  'Puerto Montt': (-72.489999999999995, -41.064999999999998),
#  'Lajes (terceira Island)': (-26.484999999999999, 39.268999999999998),
#  'Vilhena': (-59.498000000000005, -12.491),
#  'Orebro': (15.062999999999999, 59.372),
#  'Hail': (42.143000000000001, 27.728999999999999),
#  'Araracuara': (-72.016999999999996, -0.29999999999999999),
#  'Las Vegas': (-114.58799999999999, 36.133000000000003),
#  'Siem-reap': (104.354, 13.684000000000001),
#  'Bhairawa': (83.692999999999998, 27.841999999999999),
#  'Taba': (35.295999999999999, 29.978999999999999),
#  'Kandla': (70.167000000000002, 23.186999999999998),
#  'Kaitaia': (173.47499999999999, -34.450000000000003),
#  'Lyon': (5.1509999999999998, 46.210000000000001),
#  'Quincy': (-90.657999999999987, 40.570999999999998),
#  'Bojnourd': (57.513000000000005, 37.820999999999998),
#  'Tuntutuliak': (-162.44499999999999, 60.558),
#  'Fort Severn': (-87.460999999999999, 56.031000000000006),
#  'Ganja': (46.528999999999996, 41.228999999999999),
#  'Sandy Lake': (-92.907999999999987, 53.106999999999999),
#  'Anelghowhat': (170.285, -19.749000000000002),
#  'Aguascalientes': (-101.86399999999999, 22.175000000000001),
#  'Wales': (-167.49200000000002, 66.036999999999992),
#  'Kos': (27.151999999999997, 37.321999999999996),
#  'Gwadar': (62.548999999999999, 25.388000000000002),
#  'Dazhou': (107.833, 31.5),
#  'Zachar Bay': (-153.584, 57.916000000000004),
#  'Tamworth': (151.411, -30.474),
#  'Hiva-oa': (-138.35299999999998, -9.6150000000000002),
#  'Zhanjiang': (110.596, 21.356999999999999),
#  'Jacksonville NC': (-77.353999999999999, 35.381),
#  'Akron': (-81.070999999999998, 41.526000000000003),
#  'Jiamusi': (130.77500000000001, 47.405000000000001),
#  'Fernando Do Noronha': (-32.039000000000001, -3.7589999999999999),
#  'Lake Charles': (-92.706000000000003, 30.210000000000001),
#  'Rumjatar': (86.917000000000002, 27.504999999999999),
#  'Nan': (101.30500000000001, 19.346),
#  'Montego Bay': (-77.856000000000009, 18.839000000000002),
#  'Brich Creek': (-145.69299999999998, 66.426999999999992),
#  'Ronneby': (15.440999999999999, 56.443999999999996),
#  'Altamira': (-51.756999999999998, -2.7569999999999997),
#  'Liuzhou': (109.65100000000001, 24.344999999999999),
#  'Francisco Beltrao': (-52.438999999999993, -25.431999999999999),
#  'Imphal': (94.494, 25.265999999999998),
#  'Barreiras': (-45.0, -11.472999999999999),
#  'Cayo': (-81.244, 22.026999999999997),
#  'Pucon': (-71.859999999999999, -38.821999999999996),
#  'Miho': (133.393, 35.82),
#  'Phnom-penh': (105.40600000000001, 11.91),
#  'Paros': (25.212, 37.016999999999996),
#  'Iturup Island': (148.036, 45.533000000000001),
#  'Colombia': (-80.533000000000001, 34.564),
#  'Teesside': (-1.05, 54.847999999999999),
#  'Stella Maris': (-74.784999999999997, 23.969000000000001),
#  'Cobija': (-68.638999999999996, -10.401),
#  'Sangley Point': (125.79799999999999, 10.262),
#  'Basse Terre': (-62.531999999999996, 17.518000000000001),
#  'Chub Cay': (-77.801999999999992, 25.695),
#  'Antwerp': (4.7669999999999995, 51.314999999999998),
#  'West Palm Beach': (-79.492999999999995, 27.138000000000002),
#  'Tampere': (24.006999999999998, 61.689999999999998),
#  'Ayacucho': (-73.674999999999997, -12.592000000000001),
#  'President Prudente': (-51.042000000000002, -21.625999999999998),
#  'Lloydminster': (-109.455, 53.515000000000001),
#  'Karamay': (85.471000000000004, 46.027999999999999),
#  'Juiz de Fora': (-42.622, -21.189),
#  'Udaipur': (74.492999999999995, 25.029),
#  'Pattaya': (101.008, 13.132999999999999),
#  'Buonmethuot': (108.2, 13.113),
#  "Dead Man's Cay": (-74.489999999999995, 23.298000000000002),
#  'Bandar Lengeh': (55.373999999999995, 26.885999999999999),
#  'Matsumoto': (138.53700000000001, 36.277000000000001),
#  'Willemstad': (-68.933999999999997, 12.314),
#  'Phoenix': (-111.35299999999999, 33.722999999999999),
#  'Arequipa': (-71.305999999999997, -15.902000000000001),
#  'Point Salines': (-61.643999999999998, 12.007),
#  'East London': (28.375999999999998, -32.393000000000001),
#  'Takapoto': (-144.744, -14.515999999999998),
#  'T\xc3\xaate-\xc3\xa0-la-Baleine': (-58.972999999999999, 51.123999999999995),
#  'Kumejima': (127.18899999999999, 26.605),
#  'Goodnews Bay': (-161.29599999999999, 59.195),
#  'Yinchuan': (106.015, 38.803000000000004),
#  'Amilcar Cabral': (-22.916, 17.234999999999999),
#  'Hoskins': (150.67500000000001, -5.1040000000000001),
#  'Hancock': (-88.149000000000001, 47.280000000000001),
#  'Dhaka': (90.662000000000006, 24.405000000000001),
#  'Sioux Falls': (-96.569999999999993, 43.969999999999999),
#  'Laoag': (120.88500000000001, 18.295999999999999),
#  'Williams Lake': (-121.42399999999999, 52.305),
#  'Saskatoon': (-106.5, 52.283999999999999),
#  'Billund': (9.2520000000000007, 56.233000000000004),
#  'Duluth': (-91.657000000000011, 47.402999999999999),
#  'Mocamedes': (12.244000000000002, -14.769),
#  'Hasvik': (22.231999999999999, 70.811000000000007),
#  'Vernal': (-109.184, 40.734000000000002),
#  'Saratov': (46.038000000000004, 51.556999999999995),
#  'Bella Coola': (-126.32700000000001, 52.645000000000003),
#  'Jinan': (117.35899999999999, 37.428000000000004),
#  "Land's End": (-5.4510000000000005, 50.171000000000006),
#  'Aarhus': (11.030999999999999, 56.5),
#  'Santo Domingo': (-69.448999999999998, 18.715999999999998),
#  'Ganzhou': (115.52, 26.375999999999998),
#  'Healy': (-148.94899999999998, 64.444999999999993),
#  'Monroe': (-91.397000000000006, 32.850999999999999),
#  'Monterrey': (-99.512, 26.296999999999997),
#  'Santa Terezinha': (-50.171999999999997, -10.117000000000001),
#  'Ardabil': (48.707000000000001, 38.542000000000002),
#  'Ketapang': (110.605, -1.6950000000000001),
#  'Sao Paulo de Olivenca': (-68.864999999999995, -3.1099999999999999),
#  'Lazard Cardenas': (-101.70100000000001, 18.001999999999999),
#  'Badajoz': (-6.7029999999999994, 39.484999999999999),
#  'Newark': (-73.614999999999995, 41.153999999999996),
#  'Venetie': (-145.94399999999999, 67.013999999999996),
#  'Manihi': (-145.45099999999999, -14.062000000000001),
#  'Beziers': (3.589, 43.538999999999994),
#  'Gjoa Haven': (-95.75, 69.058999999999997),
#  'Sao Paulo': (-46.116000000000007, -23.054000000000002),
#  'Nikolski': (-168.74900000000002, 53.568999999999996),
#  'Kristiansand': (8.1420000000000012, 58.340000000000003),
#  'Palmas': (-47.921999999999997, -9.7370000000000001),
#  'Harrisburg': (-76.606000000000009, 40.321999999999996),
#  'Busuanga': (120.166, 12.202),
#  'Malabo': (9.1810000000000009, 4.258),
#  'Lodz': (19.663, 52.203000000000003),
#  'Natal': (-34.747, -5.8529999999999998),
#  'Emerald': (148.298, -23.280000000000001),
#  'Jonesboro': (-90.411000000000001, 36.385999999999996),
#  'Ibague': (-74.555999999999997, 4.702),
#  'Rio Gallegos': (-68.855000000000004, -51.348999999999997),
#  'Palmerston North': (176.02799999999999, -39.868000000000002),
#  'Talara': (-80.757000000000005, -4.2949999999999999),
#  'Mobile': (-87.73899999999999, 31.151999999999997),
#  'Nagpur': (79.078000000000003, 21.153000000000002),
#  'Lilongwe': (34.301000000000002, -13.649000000000001),
#  'Praia,Santiago Island': (-23.155999999999999, 15.539999999999999),
#  'Torsby': (13.652000000000001, 60.262),
#  'Sao Tome': (7.1859999999999999, 0.63),
#  'Woodbourne': (174.44999999999999, -41.198),
#  'Marseille': (5.3559999999999999, 43.725000000000001),
#  'Punta Cana': (-67.939999999999998, 18.945),
#  'Avarua': (-159.67600000000002, -20.671999999999997),
#  'Liberal': (-100.934, 37.073),
#  'Ourilandia do Norte': (-50.417000000000002, -6.6059999999999999),
#  'Corozal': (-74.810000000000002, 9.5540000000000003),
#  'Fort Mcmurray': (-110.70399999999999, 57.088000000000001),
#  'Cairo': (31.675000000000001, 30.203000000000003),
#  'Hierro': (-17.812000000000001, 28.358000000000001),
#  'Gustavus': (-135.512, 58.707999999999998),
#  'Milan': (9.4610000000000003, 45.741000000000007),
#  'San Angelo': (-100.161, 31.596),
#  'Repulse Bay': (-85.707999999999998, 66.867999999999995),
#  'Dortmund': (8.0199999999999996, 51.863),
#  'Kish Island': (54.633000000000003, 26.875999999999998),
#  'Guilin': (110.065, 25.363000000000003),
#  'Damascus': (36.856999999999999, 33.683999999999997),
#  'Salekhard': (67.018000000000001, 66.983999999999995),
#  'Jamestown': (-78.763999999999996, 42.255000000000003),
#  'Cruzeiro do Sul': (-72.616, -7.3339999999999996),
#  'El-baha': (42.056999999999995, 20.493000000000002),
#  'Humaita': (-62.453999999999994, -7.2210000000000001),
#  'Hahn': (7.4390000000000001, 50.581000000000003),
#  'Aspen': (-106.78200000000001, 39.372),
#  'Rafha': (43.817, 30.044),
#  'Chignik Lagoon': (-158.22399999999999, 56.518000000000001),
#  'Chernovtsk': (26.634, 48.431999999999995),
#  'Ahwaz': (49.268999999999998, 31.561999999999998),
#  'Hot Springs': (-92.494, 34.795999999999999),
#  'Narsaq': (-45.431000000000004, 61.527000000000001),
#  'Whale Cove': (-92.331000000000003, 62.399999999999999),
#  'Alice Springs': (134.50299999999999, -23.678000000000001),
#  'Salzburg': (13.007, 48.321999999999996),
#  'Sanikiluaq': (-78.745000000000005, 56.896000000000001),
#  'Barcelos': (-62.873999999999995, -0.95900000000000007),
#  'Pond Inlet': (-77.944999999999993, 73.138000000000005),
#  'Watertown': (-96.592000000000013, 45.523000000000003),
#  'Luzhou': (105.655, 29.420000000000002),
#  'Yaounde': (11.922000000000001, 4.2039999999999997),
#  'Gondar': (37.722999999999999, 12.866),
#  'Rota': (145.404, 14.289999999999999),
#  'Yasuj': (51.908000000000001, 31.166999999999998),
#  'Frankfurt': (8.9049999999999994, 50.043999999999997),
#  'Vinh': (106.117, 19.228999999999999),
#  'Sao Vicente Island': (-24.425000000000001, 17.388999999999999),
#  'Iguazu Falls': (-54.123000000000005, -25.563000000000002),
#  'Fort Leonardwood': (-91.567999999999998, 38.235999999999997),
#  'Jijiga': (43.311999999999998, 9.5990000000000002),
#  'Sandane': (6.1760000000000002, 62.383000000000003),
#  'Valparaiso': (-86.209000000000003, 30.805),
#  'Araxa': (-46.933999999999997, -19.272000000000002),
#  'Cuzco': (-71.897999999999996, -13.227),
#  'Nain': (-61.468000000000004, 56.914999999999999),
#  'Owensboro': (-86.612000000000009, 38.233000000000004),
#  'Ulan-ude': (107.729, 52.346000000000004),
#  'Yamaguchi': (131.464, 34.549999999999997),
#  'Noatak': (-162.959, 67.942999999999998),
#  'Maumere': (122.39399999999999, -8.402000000000001),
#  'Kerikeri': (174.51900000000001, -34.771999999999998),
#  'Chihuahua': (-105.941, 29.170999999999999),
#  'Mashhad': (59.0, 36.0),
#  'Whitehorse': (-134.446, 61.181999999999995),
#  'Brazzaville': (15.420999999999999, -3.7530000000000001),
#  'Tirupeti': (79.905000000000001, 14.054),
#  'Stavropol': (42.186999999999998, 45.181000000000004),
#  'Coral Harbour': (-82.932999999999993, 64.322000000000003),
#  'Wainwright': (-159.99200000000002, 71.063000000000002),
#  'Valesdir': (168.29499999999999, -16.660999999999998),
#  'Fort-de-france': (-60.338999999999999, 14.984999999999999),
#  'Craig Cove': (168.53999999999999, -15.775),
#  'Waco': (-96.717999999999989, 32.018000000000001),
#  'Zarzaitine': (10.071, 28.085000000000001),
#  'Pohang': (129.69999999999999, 36.646000000000001),
#  'Albury': (147.596, -35.446999999999996),
#  'Quetta': (67.561999999999998, 30.418000000000003),
#  'Faisalabad': (73.658000000000001, 31.608000000000001),
#  'Gheshm': (56.448, 27.581),
#  'Shreveport': (-93.709999999999994, 32.744),
#  'Mesa': (-111.425, 33.513000000000005),
#  'Al-Jawf': (40.165999999999997, 30.308000000000003),
#  'Penzance': (-5.1979999999999995, 50.213000000000001),
#  'Holman Island': (-117.67700000000001, 71.271000000000001),
#  'Okha': (143.55500000000001, 53.972000000000001),
#  'Malindi': (40.169000000000004, -2.7160000000000002),
#  'Salerno': (15.517999999999999, 41.033999999999999),
#  'Sendai': (141.52799999999999, 38.231999999999999),
#  'Agadir': (-9.2439999999999998, 30.635000000000002),
#  'Charleston': (-79.40100000000001, 33.497),
#  'Hyeres': (6.2429999999999994, 43.161999999999999),
#  'Igiugig': (-155.83700000000002, 59.539999999999999),
#  'Wroclaw': (17.475999999999999, 51.171000000000006),
#  'Mekoryuk': (-165.785, 60.619),
#  'Canberra': (149.32499999999999, -34.844999999999999),
#  'Wagga Wagga': (147.77700000000002, -34.609000000000002),
#  'Taupo': (176.13999999999999, -38.567),
#  'Craig': (-132.58000000000001, 55.798000000000002),
#  'Akita': (140.364, 40.024999999999999),
#  'Belgorod': (36.983000000000004, 51.073),
#  'Volgograd': (44.575000000000003, 49.303999999999995),
#  'Trinidad': (-64.86399999999999, -14.698),
#  'Chicago': (-87.842000000000013, 42.631),
#  'Farmington': (-107.71700000000001, 37.234999999999999),
#  'San Salvador': (-88.427000000000007, 13.734000000000002),
#  'What\xc3\xac': (-116.744, 63.218999999999994),
#  "Yan'an": (109.92299999999999, 37.061),
#  'Pentecost Island': (168.25299999999999, -15.118),
#  'Nuqu\xc3\xad': (-76.799999999999997, 6.1660000000000004),
#  'Port Williams': (-152.304, 58.816000000000003),
#  'Charlottetown': (-62.536000000000001, 46.483000000000004),
#  'Ciudad Victoria': (-98.927999999999997, 24.171999999999997),
#  'Tashkent': (69.468000000000004, 41.428999999999995),
#  'Quimper': (-3.613, 48.623999999999995),
#  'Balmaceda': (-71.483000000000004, -45.861000000000004),
#  'Shinyanga': (33.695, -3.4449999999999998),
#  'Grand Rapids': (-85.204999999999998, 43.468000000000004),
#  'Bella Bella': (-127.44, 52.231999999999999),
#  'Porbandar': (70.094999999999999, 22.081),
#  'Arauca': (-70.561999999999998, 7.1139999999999999),
#  'Dothan': (-85.082999999999998, 31.535),
#  'Point Baker': (-133.37100000000001, 56.586000000000006),
#  'Chongqing': (107.069, 30.198),
#  'Lorient': (-3.0669999999999997, 48.266999999999996),
#  'Bakersfield': (-118.428, 35.722000000000001),
#  'Port Hardy': (-126.94499999999999, 51.133999999999993),
#  'Bahias Dehuatulco': (-95.771000000000001, 16.292000000000002),
#  'Lago Agrio': (-76.780000000000001, 0.155),
#  'Koyuk': (-160.59100000000001, 65.564999999999998),
#  'Kangiqsujuaq': (-71.882999999999996, 61.981000000000002),
#  'Churchill Falls': (-63.511000000000003, 53.936000000000007),
#  'Ras Al Khaimah': (56.563999999999993, 26.021999999999998),
#  'Pangkalan Bun': (112.12200000000001, -2.5089999999999999),
#  'Tabubil': (141.376, -4.798),
#  'Tbilisi': (45.591000000000001, 42.115000000000002),
#  'Savoonga': (-170.155, 64.143999999999991),
#  'Mariehamn': (20.495999999999999, 60.203000000000003),
#  'Kichinau Fir/acc/com': (29.550999999999998, 47.546000000000006),
#  'Glendive': (-104.679, 47.231000000000002),
#  'Raivavae': (-147.44999999999999, -23.784000000000002),
#  'Saint George': (-113.322, 37.149999999999999),
#  'Sofia': (23.675999999999998, 43.158000000000001),
#  'Bharatpur': (84.715000000000003, 28.129999999999999),
#  'Djerba': (11.292, 34.457999999999998),
#  'Lisbon': (-8.5600000000000005, 39.302),
#  'Antalya': (31.334, 37.497),
#  'Copenhagen': (13.093, 56.028999999999996),
#  'Pellston': (-84.662000000000006, 45.951000000000001),
#  'Kitale': (35.597000000000001, 1.619),
#  'Zanzibar': (39.374000000000002, -5.7039999999999997),
#  'Gam\xc3\xa8t\xc3\xac': (-116.84999999999999, 64.192999999999998),
#  'Chignik Lake': (-158.626, 56.424999999999997),
#  'Kiev': (31.491, 50.575000000000003),
#  'Albany': (-73.670000000000002, 43.247),
#  'New Stuyahok': (-156.88, 59.748999999999995),
#  'Ndola': (29.108000000000001, -12.997),
#  'Presque Isle': (-67.408000000000001, 47.148000000000003),
#  'Limbang': (115.01700000000001, 5.3470000000000004),
#  'Altenrhein': (9.9339999999999993, 47.808),
#  'Honningsvag': (26.383000000000003, 71.650000000000006),
#  'Gunnison': (-106.889, 38.889000000000003),
#  'Abakan': (91.641000000000005, 54.233000000000004),
#  'Bhopal': (77.561999999999998, 23.478999999999999),
#  'Santiago': (-70.643999999999991, -32.989000000000004),
#  'Kota Kinabalu': (116.08499999999999, 6.5620000000000003),
#  'Fort Good Hope': (-128.417, 66.444000000000003),
#  'Coolangatta': (153.84100000000001, -27.608000000000001),
#  'Sihanoukville': (104.06100000000001, 10.965999999999999),
#  'Sovetskiy': (64.007000000000005, 61.533000000000001),
#  'Makale': (39.889000000000003, 13.777999999999999),
#  'Tamale': (-0.77300000000000002, 9.927999999999999),
#  'Maroochydore': (153.15100000000001, -26.339000000000002),
#  'Sao Luis': (-43.723999999999997, -2.3090000000000002),
#  'Nantes': (-1.3519999999999999, 47.255000000000003),
#  'Mwanza': (33.554000000000002, -2.0750000000000002),
#  'Fuyang': (116.361, 33.5),
#  'Havana': (-82.016000000000005, 23.648000000000003),
#  'Aomori': (141.15100000000001, 41.223999999999997),
#  'Sfax': (11.151, 35.195999999999998),
#  'Chittagong': (92.355000000000004, 22.416),
#  'Tatalina': (-155.96100000000001, 63.490000000000002),
#  'Ipota': (169.51300000000001, -18.797999999999998),
#  'Magnetiogorsk': (59.258999999999993, 53.655000000000001),
#  'Dodge City': (-99.942999999999998, 38.271999999999998),
#  'Blackall': (145.714, -24.046999999999997),
#  'Malanje': (16.52, -9.2089999999999996),
#  'Washington': (-77.093999999999994, 39.573999999999998),
#  'Haugesund': (5.3470000000000004, 59.575000000000003),
#  'Tyler': (-95.003999999999991, 32.590000000000003),
#  'Conakry': (-13.354000000000001, 9.9610000000000003),
#  'Lampang': (99.840000000000003, 18.451000000000001),
#  'Juiz De Fora': (-42.978000000000002, -21.653000000000002),
#  'Tokushima': (135.011, 34.220999999999997),
#  'Mammoth Lakes': (-118.73, 38.039999999999999),
#  'Malta': (14.795, 36.429000000000002),
#  'Adrar': (0.35499999999999998, 28.395),
#  'Jackson': (-89.459999999999994, 32.518000000000001),
#  'Caracas': (-66.984999999999999, 11.005000000000001),
#  'Pantelleria': (12.614000000000001, 37.359999999999999),
#  'St. Anthony': (-55.472000000000001, 51.652999999999999),
#  'Rimatara': (-152.67600000000002, -22.396000000000001),
#  'Sydney': (151.29499999999999, -33.911000000000001),
#  'Atiu Island': (-157.53200000000001, -19.946999999999999),
#  'Kostanay': (63.917000000000002, 53.343999999999994),
#  'New Plymouth': (174.298, -38.347999999999999),
#  'Jodhpur': (73.081000000000003, 26.418000000000003),
#  'Varginha': (-45.123000000000005, -21.316999999999997),
#  'Atqasuk': (-157.06, 70.778000000000006),
#  'Ufa': (56.457000000000001, 54.928999999999995),
#  'Red Devil': (-156.91800000000001, 62.313000000000002),
#  'Djibouti': (43.265000000000001, 11.912000000000001),
#  'Guayana': (-62.601000000000006, 8.4800000000000004),
#  'Puntarenas': (-83.402999999999992, 9.1980000000000004),
#  'Amook Bay': (-153.69299999999998, 57.784999999999997),
#  'San Antonio': (-98.117000000000004, 29.888999999999999),
#  'Naha': (125.88, 4.1379999999999999),
#  'Weeze': (6.2360000000000007, 52.003),
#  'Mason City': (-93.012, 43.373999999999995),
#  'Mount Hagen': (144.49299999999999, -5.7120000000000006),
#  "Governor's Harbor": (-75.88600000000001, 25.474),
#  'Central': (-144.63499999999999, 65.956000000000003),
#  'Stavanger': (6.0629999999999997, 59.461000000000006),
#  'Trollhattan': (12.574999999999999, 58.530000000000001),
#  'Setif': (5.54, 36.295999999999999),
#  'Fuzhou': (120.105, 26.558000000000003),
#  'Maringa': (-51.361000000000004, -23.128),
#  'Aviles': (-5.3920000000000003, 43.938999999999993),
#  'Kenora': (-93.938999999999993, 50.313000000000002),
#  'Cheboksary': (47.578000000000003, 56.149999999999999),
#  'Friedrichshafen': (9.8520000000000003, 48.118000000000002),
#  'Ponta Delgada': (-25.497, 38.234999999999999),
#  'Cayo Coco': (-78.185000000000002, 22.855),
#  'Erbil': (44.604999999999997, 36.396000000000001),
#  'Hagfors': (13.964, 60.033000000000001),
#  'Tachina': (-79.378, 1.6299999999999999),
#  'Champaign': (-87.797000000000011, 40.064999999999998),
#  'Merzifon': (35.869, 41.381999999999998),
#  'North Ronaldsay': (-2.0580000000000003, 59.611999999999995),
#  'Olbia': (9.8620000000000001, 41.497),
#  'Aberdeen': (-1.663, 57.336000000000006),
#  'Palm Springs': (-116.178, 34.381999999999998),
#  'Jining': (116.88799999999999, 35.695),
#  'Rondonopolis': (-54.388999999999996, -16.112000000000002),
#  'Baghdogra': (88.547000000000011, 27.135000000000002),
#  'Rodriguez Island': (63.601000000000006, -19.597000000000001),
#  'Molokai': (-156.494, 21.254000000000001),
#  'Ust Kamenogorsk': (82.822999999999993, 50.061000000000007),
#  'San Tome': (-63.586000000000006, 9.5749999999999993),
#  'Alamogordo': (-105.985, 33.399000000000001),
#  'Aswan': (33.366, 24.606999999999999),
#  'Asyut': (31.019000000000002, 27.076999999999998),
#  'Pristina': (21.059000000000001, 42.953999999999994),
#  'Muscat': (58.473999999999997, 23.988000000000003),
#  'Alor Setar': (100.663, 6.3159999999999998),
#  'Kerry': (-9.2070000000000007, 52.301000000000002),
#  'Phucat': (109.06999999999999, 14.590999999999999),
#  'Zakynthos': (21.473000000000003, 38.250999999999998),
#  'Manaus': (-59.417000000000002, -2.3980000000000001),
#  'Larnaca': (34.040999999999997, 35.457999999999998),
#  'Manzhouli': (117.54899999999999, 49.943999999999996),
#  'Berbera': (45.568000000000005, 10.648),
#  'Gyumri': (44.431999999999995, 41.25),
#  'Belize': (-87.829999999999998, 17.890000000000001),
#  'Maupiti': (-151.74000000000001, -16.045000000000002),
#  'New Bedford': (-70.929000000000002, 42.126000000000005),
#  'Tokyo': (140.643, 36.274000000000001),
#  'Mopti': (-3.4660000000000002, 14.854000000000001),
#  'Shaktoolik': (-160.70699999999999, 64.617999999999995),
#  'Roi Et': (104.289, 16.194000000000003),
#  'Bhaunagar': (72.308000000000007, 22.253),
#  'Trang': (100.027, 7.8470000000000004),
#  'Calicut': (76.591999999999999, 11.228),
#  'Salluit': (-75.445999999999998, 62.298999999999999),
#  'Fayetteville': (-78.801000000000002, 35.652000000000001),
#  'West Tinian': (146.03200000000001, 15.664999999999999),
#  'Bozeman': (-110.601, 46.296000000000006),
#  'Brindisi': (18.577999999999999, 41.096000000000004),
#  'Andoya': (16.239999999999998, 69.486999999999995),
#  'Silchar': (93.631, 25.521000000000001),
#  'Elim': (-161.785, 65.025000000000006),
#  'Walla Walla': (-117.81399999999999, 46.158000000000001),
#  'Mayaguez': (-66.581000000000003, 18.425999999999998),
#  'Rahim Yar Khan': (70.465000000000003, 28.638999999999999),
#  'Cat Lake': (-91.707999999999998, 52.211999999999996),
#  'St. George': (-169.44, 56.961999999999996),
#  'Cleveland': (-81.75, 41.686000000000007),
#  'Hopedale': (-59.715000000000003, 55.747),
#  'Aurillac': (2.7030000000000003, 45.484999999999999),
#  'Isle Of Man': (-4.3739999999999997, 54.138000000000005),
#  'Grozny': (46.306000000000004, 43.496000000000002),
#  'Sault Ste Marie': (-84.121000000000009, 46.417999999999999),
#  'Vineyard Haven MA': (-70.358999999999995, 41.652000000000001),
#  'Tianjin': (117.57600000000001, 39.207000000000001),
#  'Santarem': (-54.655000000000001, -2.0380000000000003),
#  'Turbat': (63.049999999999997, 26.643000000000001),
#  'Athens': (24.574000000000002, 38.560000000000002),
#  'Clarksburg': (-79.713999999999999, 39.494),
#  'Satu Mare': (23.475999999999999, 48.171999999999997),
#  'Neuquen': (-67.593000000000004, -38.914999999999999),
#  'Villahermosa': (-92.695999999999998, 18.660999999999998),
#  'Oradea': (22.504000000000001, 47.042000000000002),
#  'Puerto Lempira': (-83.63600000000001, 15.437000000000001),
#  'Cordova': (-145.13, 60.818999999999996),
#  'Hibbing': (-92.732000000000014, 47.643999999999998),
#  'Georgetown': (-80.930000000000007, 19.487000000000002),
#  'Villavicencio': (-73.356999999999999, 4.2789999999999999),
#  'Cockburn Town': (-70.570999999999998, 21.739999999999998),
#  'Vorkuta': (64.655000000000001, 67.813999999999993),
#  'Sinop': (-55.100000000000001, -11.75),
#  'Prestwick': (-4.3120000000000003, 55.848999999999997),
#  'Newman': (120.33799999999999, -23.030000000000001),
#  'Chongju': (127.831, 37.194000000000003),
#  'Umiujaq': (-76.198000000000008, 56.893000000000001),
#  'Garden City': (-100.541, 38.545000000000002),
#  'Iki': (130.309, 34.248000000000005),
#  'Hall Beach': (-80.739999999999995, 69.293000000000006),
#  'Tebessa': (8.2010000000000005, 35.719000000000001),
#  'Kimberley': (25.274999999999999, -28.671999999999997),
#  'Budapest': (19.425000000000001, 47.728000000000002),
#  'Heihe': (127.5, 50.416000000000004),
#  'Bydgoszcz': (18.629000000000001, 53.161000000000001),
#  'Jakarta': (107.09299999999999, -5.5429999999999993),
#  'Gaya': (85.584999999999994, 25.239999999999998),
#  'Freeport': (-78.492999999999995, 26.930999999999997),
#  'Xichang': (102.307, 28.648000000000003),
#  'Hollis': (-132.411, 55.802),
#  'Bearskin Lake': (-90.378999999999991, 54.608999999999995),
#  'Santa Marta': (-73.718000000000004, 11.199000000000002),
#  'Bristol': (-2.532, 51.637),
#  'Hemavan': (15.137, 66.343000000000004),
#  'Holy Cross': (-159.625, 62.313000000000002),
#  'La Paz': (-67.653999999999996, -16.189),
#  'Tijuana': (-116.95100000000001, 32.900999999999996),
#  'Pelican': (-135.72799999999998, 58.591999999999999),
#  'Yap': (138.137, 9.8309999999999995),
#  'Levelock': (-156.76499999999999, 59.213000000000001),
#  'Durango': (-107.59, 37.251999999999995),
#  'Parma': (10.493, 45.373999999999995),
#  'Kiunga': (141.47, -5.5429999999999993),
#  'Blantyre': (35.623000000000005, -15.465999999999999),
#  'Des Moines': (-93.438999999999993, 41.888999999999996),
#  'Portland': (-122.33, 45.981000000000002),
#  'Piura': (-80.361000000000004, -4.6769999999999996),
#  'Red Lake': (-93.656000000000006, 51.111000000000004),
#  'Kerman': (57.585000000000001, 30.456999999999997),
#  'Bakalalan': (116.03, 4.6230000000000002),
#  'Grayling': (-159.44200000000001, 63.490000000000002),
#  'Madinah': (40.174999999999997, 24.921999999999997),
#  'Riberalta': (-66.0, -11.0),
#  'Port Heiden': (-158.38900000000001, 57.597999999999999),
#  'Mitiaro Island': (-157.505, -19.738),
#  'Diu': (71.534999999999997, 21.188000000000002),
#  'Nicosia': (33.826000000000001, 35.256999999999998),
#  'Shenzhen': (114.351, 23.065000000000001),
#  'Zaragoza': (-0.40299999999999997, 42.109999999999999),
#  'Timmins': (-80.962000000000003, 48.948999999999998),
#  'Bloemfontein': (26.504000000000001, -28.488000000000003),
#  'Yancheng': (120.208, 33.641999999999996),
#  "Xi'an": (109.25200000000001, 34.744999999999997),
#  'Baghdad': (44.390000000000001, 33.436999999999998),
#  'Flint': (-83.572999999999993, 43.608999999999995),
#  'Kithira': (23.028000000000002, 36.457000000000001),
#  'Ovda': (35.558999999999997, 30.566999999999997),
#  'Marsa Alam': (34.972000000000001, 25.928000000000001),
#  'Al Ghaidah Intl': (52.291000000000004, 16.319000000000003),
#  'Tampa': (-82.222999999999999, 28.625),
#  'Bangda': (97.180000000000007, 30.921999999999997),
#  'Leknes': (14.015000000000001, 68.253999999999991),
#  'Alakanuk': (-164.43400000000003, 63.133000000000003),
#  'Mount Pleasant': (-58.078999999999994, -51.704999999999998),
#  'Mexicali': (-114.73700000000001, 33.051000000000002),
#  'Lampedusa': (13.029999999999999, 35.829000000000001),
#  'Juba': (32.000999999999998, 5.4529999999999994),
#  'Lethbridge': (-112.667, 50.049999999999997),
#  'Tel-aviv': (35.476999999999997, 32.018000000000001),
#  'Denpasar': (115.27799999999999, -8.5809999999999995),
#  'Hotan': (80.441000000000003, 37.064),
#  'Tabatinga': (-69.893999999999991, -3.7599999999999998),
#  'Valdivia': (-72.477000000000004, -39.417000000000002),
#  'Maca\xc3\xa9': (-41.609999999999999, -21.905000000000001),
#  'Texarkana': (-93.986000000000004, 33.756),
#  'Fresno': (-119.53100000000001, 37.292999999999999),
#  'Norfolk Island': (168.56400000000002, -28.403000000000002),
#  'Anta': (-77.331000000000003, -8.9130000000000003),
#  'Bisha': (43.033999999999999, 20.640000000000001),
#  'Decatur': (-88.777000000000001, 40.390000000000001),
#  'Tawau': (118.20299999999999, 4.5220000000000002),
#  'Ithaca': (-76.097999999999999, 42.818000000000005),
#  'Yulin': (110.21799999999999, 38.448),
#  'Douala': (10.199, 4.0099999999999998),
#  'Tuktoyaktuk': (-132.37799999999999, 69.721999999999994),
#  'Kununurra': (129.179, -15.630999999999998),
#  'Nyala': (25.593000000000004, 12.089),
#  'Sheridan': (-106.96700000000001, 45.281999999999996),
#  'Samarkand': (67.638999999999996, 40.167000000000002),
#  'Kaohsiung': (120.583, 22.960999999999999),
#  'Fargo': (-96.692999999999998, 47.533999999999999),
#  'Concepcion': (-72.438999999999993, -36.622),
#  'Saipan': (146.215, 15.198),
#  'Edinburgh': (-2.9550000000000001, 56.582999999999998),
#  'Rouyn': (-78.725999999999999, 48.343000000000004),
#  'Saltillo': (-100.88200000000001, 25.914999999999999),
#  'Quito': (-78.147999999999996, 0.43099999999999999),
#  'Ajaccio': (9.3379999999999992, 42.538999999999994),
#  'Leh': (77.909999999999997, 34.225999999999999),
#  'Peoria': (-89.48899999999999, 41.106999999999999),
#  'Worland': (-107.919, 44.608999999999995),
#  'Prosserpine': (148.91999999999999, -20.159000000000002),
#  'Armenia': (-75.611000000000004, 4.7539999999999996),
#  'Resistencia': (-58.427, -27.084),
#  'Kristianstad': (14.142000000000001, 56.536000000000001),
#  'Waskaganish': (-78.597999999999999, 51.788000000000004),
#  'Syracuse': (-75.51100000000001, 43.185000000000002),
#  'Graz': (15.732000000000001, 47.651000000000003),
#  'Bodrum': (28.34, 38.366),
#  'Rodez': (2.8039999999999998, 44.678999999999995),
#  'Freetown': (-12.66, 9.027000000000001),
#  'Joensuu': (30.011999999999997, 63.103999999999999),
#  'Cape Town': (19.001999999999999, -33.942),
#  'Fort Hope': (-87.847000000000008, 51.936000000000007),
#  'Changzhou': (120.18600000000001, 32.569000000000003),
#  'Longyan': (117.24299999999999, 26.123000000000001),
#  'Huai An': (119.24600000000001, 34.295000000000002),
#  'The Valley': (-62.426000000000002, 18.340999999999998),
#  'Madison': (-88.896000000000001, 43.233000000000004),
#  'Florianopolis': (-48.246000000000002, -27.451000000000001),
#  'Grise Fiord': (-82.84899999999999, 76.709999999999994),
#  'Hafr Al-batin': (46.207999999999998, 28.558000000000003),
#  'Narssarssuaq': (-45.043999999999997, 61.266999999999996),
#  'Cajamarca': (-78.149000000000001, -6.5659999999999998),
#  'Ghardaia': (4.3230000000000004, 32.640000000000001),
#  'Fort Dodge': (-93.653999999999996, 42.917999999999999),
#  'Floro': (5.0410000000000004, 61.972000000000001),
#  'Placencia': (-87.937000000000012, 16.894000000000002),
#  'Alta Floresta': (-55.511000000000003, -9.777000000000001),
#  'Lugano': (9.5170000000000012, 46.006999999999998),
#  'Dallas': (-96.752999999999986, 33.411000000000001),
#  'Guaymas': (-110.876, 28.614000000000001),
#  'El Aai\xc3\xban': (-12.699000000000002, 27.251999999999999),
#  'Valdez': (-145.74799999999999, 61.222999999999999),
#  'Sitka': (-134.93700000000001, 57.078000000000003),
#  'Adana': (35.466999999999999, 37.635999999999996),
#  'Poprad': (20.401, 49.122),
#  'Santiago De Cuba': (-75.725999999999999, 20.616),
#  'Fez': (-4.9639999999999995, 34.545000000000002),
#  'Limoges': (1.2990000000000002, 46.436999999999998),
#  'Cabo Frio': (-41.457000000000001, -22.870000000000001),
#  'Hanamaki': (141.22499999999999, 39.713999999999999),
#  'Gisenyi': (29.430999999999997, -1.4630000000000001),
#  'Doncaster,Sheffield': (-0.34100000000000003, 53.791000000000004),
#  'Hana': (-155.358, 21.326000000000001),
#  'Firenze': (11.340999999999999, 44.348999999999997),
#  'Gambella': (34.938000000000002, 8.2140000000000004),
#  'Puvirnituq': (-76.811999999999998, 60.083999999999996),
#  'Jorhat': (94.292000000000002, 27.219000000000001),
#  'Gafsa': (9.3699999999999992, 34.703000000000003),
#  'Ende': (122.101, -8.7490000000000006),
#  'Lexington KY': (-84.343999999999994, 38.060000000000002),
#  'Afutara': (161.58199999999999, -8.6389999999999993),
#  'Port Protection': (-133.34999999999999, 56.548000000000002),
#  'Nanyuki': (37.055, 0.55500000000000005),
#  'Allahabad': (82.222999999999999, 25.733000000000001),
#  'Sanya': (109.68700000000001, 18.504000000000001),
#  'Fak Fak': (132.44499999999999, -2.867),
#  'Ludhiaha': (76.587000000000003, 31.423999999999999),
#  'Eek': (-161.40700000000001, 60.356000000000002),
#  'Baia Mare': (23.783000000000001, 48.097000000000001),
#  'Las Palmas': (-13.343, 29.574999999999999),
#  'Reykjavik': (-21.901, 64.216000000000008),
#  'Bahia Blanca': (-61.616000000000007, -38.542000000000002),
#  'Emmonak': (-164.15200000000002, 63.310000000000002),
#  'Rio Grande': (-67.582999999999998, -53.630000000000003),
#  'Groningen': (6.9649999999999999, 53.198999999999998),
#  'Wuzhou': (111.413, 23.760999999999999),
#  'Horta': (-28.526999999999997, 38.866),
#  'Brest': (-4.0310000000000006, 48.746000000000002),
#  'Kagoshima': (131.19899999999998, 32.338000000000001),
#  'Townsville': (147.27500000000001, -18.754999999999999),
#  'Granada': (-3.6289999999999996, 37.314),
#  'Nhatrang': (109.31999999999999, 12.379000000000001),
#  'Quesnel': (-122.184, 53.042999999999999),
#  'Pensacola': (-86.644999999999996, 30.789000000000001),
#  'Maputo': (32.954000000000001, -25.869),
#  'Raipur': (82.231000000000009, 21.300000000000001),
#  'Lhasa': (91.518999999999991, 29.495999999999999),
#  'Masbate': (124.04799999999999, 12.615),
#  'Porto Alegre': (-50.619999999999997, -29.991),
#  'Muan': (126.637, 35.652000000000001),
#  'Rock Sound': (-75.629999999999995, 25.486000000000001),
#  'Roxana': (-83.192000000000007, 10.948),
#  'Rennell Island': (160.10499999999999, -11.224),
#  'Masset': (-131.542, 54.045000000000002),
#  'Kudat': (117.39299999999999, 7.5370000000000008),
#  'Iron Mountain': (-87.525000000000006, 46.363),
#  'Gizo': (157.44, -7.4970000000000008),
#  'San Pedro Sula': (-87.87299999999999, 15.754000000000001),
#  'Cicia': (-178.90400000000002, -17.573),
#  'Newquai': (-4.9930000000000003, 50.733999999999995),
#  'Marshall': (-161.37700000000001, 62.441000000000003),
#  'Puerto Maldonado': (-68.715000000000003, -12.357000000000001),
#  'Wichita': (-97.055999999999997, 38.082999999999998),
#  'Oita': (132.22799999999998, 33.798999999999999),
#  'Melbourne': (145.405, -37.455999999999996),
#  'Kamuela': (-155.447, 20.001999999999999),
#  'Haiphong': (107.208, 21.364999999999998),
#  'Bilbao': (-2.8519999999999999, 43.501000000000005),
#  'Kuantan': (103.348, 4.2919999999999998),
#  'Turany': (17.157, 49.251999999999995),
#  'Mudgee': (150.018, -32.271000000000001),
#  'Dalian': (121.89700000000001, 39.609000000000002),
#  'Faleolo': (-171.34799999999998, -13.717000000000001),
#  'Doha': (51.941000000000003, 25.434999999999999),
#  'Papeete': (-149.35299999999998, -17.262),
#  'Tupelo': (-88.617000000000004, 34.445999999999998),
#  'Flores (flores Isl.)': (-30.553000000000001, 39.758000000000003),
#  'Long Akah': (115.30500000000001, 3.5),
#  'Treasure Cay': (-76.986000000000004, 27.241999999999997),
#  'Samara': (50.25, 53.832999999999998),
#  'Ivano-Frankivsk': (25.143000000000001, 49.472999999999999),
#  'Williamsport': (-76.869, 41.402999999999999),
#  'Kinshasa': (15.74, -3.9769999999999999),
#  'Madras': (80.299999999999997, 13.657),
#  'Miles City': (-105.81, 46.713000000000001),
#  'Torino': (8.0820000000000007, 45.333999999999996),
#  'Dundee': (-2.3769999999999998, 56.753999999999998),
#  'Umea': (20.471, 64.319000000000003),
#  'Ziguinchor': (-15.802999999999999, 12.925999999999998),
#  'St.-denis': (55.850000000000001, -20.811999999999998),
#  'Columbia': (-91.700000000000003, 39.363),
#  'North Whale Pass': (-132.53700000000001, 56.193000000000005),
#  'King Salmon': (-156.416, 59.126999999999995),
#  'Lihue': (-158.899, 22.625999999999998),
#  'El Paso': (-105.96299999999999, 32.344999999999999),
#  'Huhhot': (112.37299999999999, 41.418999999999997),
#  'Yuma': (-114.34399999999999, 33.094000000000001),
#  'Atlanta': (-84.047000000000011, 34.061),
#  'Ahmedabad': (73.057000000000002, 23.128),
#  'Figari': (9.1620000000000008, 41.833999999999996),
#  'Tanjung Pandan': (108.258, -2.577),
#  'Trelew': (-64.783999999999992, -42.685000000000002),
#  'Manokwari': (134.08100000000002, -0.81999999999999995),
#  'Kigali': (30.231999999999999, -1.9480000000000002),
#  'Scranton': (-75.540000000000006, 41.563999999999993),
#  'Telluride': (-107.848, 38.588999999999999),
#  'Quujjuaq': (-68.045000000000002, 58.159999999999997),
#  'Graciosa Island': (-27.384, 39.152999999999999),
#  'Blagoveschensk': (127.68700000000001, 50.707999999999998),
#  'Dourados': (-54.677, -21.701999999999998),
#  'Sao Jose Do Rio Preto': (-49.011000000000003, -20.695),
#  'Kodiak': (-152.15700000000001, 58.248999999999995),
#  'Harbin': (126.417, 46.038999999999994),
#  'Mananara': (50.288999999999994, -15.607000000000001),
#  'Skelleftea': (21.128, 65.040999999999997),
#  'Nevsehir': (34.890000000000001, 39.286000000000001),
#  'Kanpur': (80.608000000000004, 26.734999999999999),
#  'Barra': (-7.0720000000000001, 57.038000000000004),
#  'Matei': (-179.79499999999999, -16.484999999999999),
#  'Ouagadougou': (-1.1879999999999999, 12.587999999999999),
#  'Puerto Plata': (-70.283999999999992, 20.262999999999998),
#  'Sohag': (32.238, 26.568000000000001),
#  'Santa Barbara': (-119.73399999999999, 34.710000000000001),
#  'Tak': (98.907999999999987, 17.166),
#  'Rostov': (40.363, 47.43),
#  'Kuqa': (83.643999999999991, 42.196000000000005),
#  'Ulan Bator': (107.277, 48.405000000000001),
#  'North Platte': (-100.47399999999999, 41.210000000000001),
#  'Gisborne': (178.63, -38.439),
#  'Burlington': (-72.588999999999999, 44.786000000000001),
#  'Puerto In\xc3\xadrida': (-67.849999999999994, 4.4160000000000004),
#  'Romblon': (122.14100000000001, 12.517999999999999),
#  'Thimphu': (89.707000000000008, 27.670999999999999),
#  'Hervey Bay': (153.46700000000001, -24.864999999999998),
#  'Majuro': (171.453, 7.1070000000000002),
#  'Conson': (107.054, 9.2189999999999994),
#  'Guangzhou': (113.49700000000001, 23.654),
#  'Hefei': (117.49700000000001, 32.299999999999997),
#  'Kuala Lumpur': (102.18299999999999, 3.242),
#  'Luoyang': (112.46600000000001, 34.683),
#  'Honolulu': (-157.87100000000001, 21.530999999999999),
#  'Bern': (7.8279999999999994, 47.523000000000003),
#  'Grenoble': (5.5479999999999992, 45.603999999999999),
#  'Nandayure': (-84.952000000000012, 10.425999999999998),
#  'Timimoun': (0.46000000000000002, 29.395),
#  'Klamath Falls': (-121.55500000000001, 42.259999999999998),
#  'Forli': (12.116, 44.323999999999998),
#  'Paderborn': (9.027000000000001, 52.023000000000003),
#  'Rabat': (-6.5860000000000003, 34.085000000000001),
#  'Youngstown': (-80.466000000000008, 41.433999999999997),
#  'Paama Island': (168.428, -16.065000000000001),
#  'Sebha': (14.787000000000001, 27.644000000000002),
#  'Shire Indasilase': (38.454000000000001, 14.130000000000001),
#  'Crotone': (17.132999999999999, 39.661999999999999),
#  'Punta del Este': (-54.491000000000007, -34.759),
#  'Uberaba': (-47.942, -19.609000000000002),
#  'Lawton': (-98.027999999999992, 34.945999999999998),
#  'Samburu South': (37.890000000000001, 0.88400000000000001),
#  'Lhok Seumawe-Sumatra Island': (97.582999999999998, 5.3770000000000007),
#  'Khudzhand': (70.156999999999996, 40.359000000000002),
#  'Campbeltown': (-5.4779999999999998, 55.728000000000002),
#  'Malacca': (102.419, 2.4380000000000002),
#  'Sumburgh': (-0.82599999999999996, 60.463999999999999),
#  'Wrangell': (-131.94999999999999, 56.806999999999995),
#  'Mudanjiang': (129.94799999999998, 44.873000000000005),
#  'La Tabati\xc3\xa8re': (-58.960000000000001, 51.383999999999993),
#  'Kingfisher Lake': (-89.759, 53.020000000000003),
#  'Entebbe': (32.739000000000004, 0.070000000000000007),
#  'Lansing': (-84.312999999999988, 43.296999999999997),
#  'Bellona': (16.635999999999999, -10.852),
#  'Manokotak': (-158.417, 59.649999999999999),
#  'McCook': (-100.321, 40.343000000000004),
#  'Bacau': (27.516999999999999, 46.869),
#  'Sao Joao del Rei': (-43.710000000000001, -20.477999999999998),
#  'Redmond-Bend': (-120.584, 44.423000000000002),
#  'Altay': (88.194000000000003, 48.443999999999996),
#  'Dibrugarh': (95.027999999999992, 27.805999999999997),
#  'Sarasota': (-82.257999999999996, 27.659000000000002),
#  'South Bend': (-85.863, 42.181000000000004),
#  'Webequie': (-86.948999999999998, 53.598999999999997),
#  'Macon': (-83.415999999999997, 33.154000000000003),
#  'Gdansk': (18.777000000000001, 54.628999999999998),
#  'Khasab': (56.399999999999999, 26.284000000000002),
#  'Malaga': (-4.1660000000000004, 37.124000000000002),
#  'Kazan': (49.463999999999999, 56.009999999999998),
#  'F': (-104.35299999999999, 40.753),
#  'Coppermine': (-114.574, 68.361000000000004),
#  'Kardla': (23.384, 59.651000000000003),
#  'Pokhara': (84.63600000000001, 28.334),
#  'Orlando': (-80.84899999999999, 28.715),
#  'Asosa': (34.976999999999997, 10.029999999999999),
#  'Lewistown': (-109.11200000000001, 47.082000000000001),
#  'Genoa': (9.3949999999999996, 44.688000000000002),
#  'Mangalore': (75.483000000000004, 13.602),
#  'Montreal': (-73.569000000000003, 45.783999999999999),
#  'Thief River Falls': (-95.64200000000001, 48.108999999999995),
#  'Bata': (10.342000000000001, 2.5089999999999999),
#  'Saga': (130.50299999999999, 33.249000000000002),
#  'New Bern': (-76.405000000000001, 35.121000000000002),
#  'Lebanon': (-71.841000000000008, 44.042999999999999),
#  'Oranjemund': (16.744, -28.308000000000003),
#  'Hermosillo': (-110.414, 29.159000000000002),
#  'Sukhothai': (100.363, 17.396000000000001),
#  'Tallinn-ulemiste International': (25.388000000000002, 59.688000000000002),
#  'Kupang': (124.11799999999999, -9.6199999999999992),
#  'Larsen Bay': (-153.96200000000002, 57.891000000000005),
#  'Contadora Island': (-78.391999999999996, 9.0470000000000006),
#  'Matamoros': (-97.209000000000003, 26.283000000000001),
#  'Kristiansund': (8.3740000000000006, 63.186000000000007),
#  'Great Exuma': (-75.796999999999997, 23.936999999999998),
#  'Algier': (3.359, 37.150999999999996),
#  'Guanambi': (-42.638999999999996, -13.695),
#  'Tuy Hoa': (109.556, 13.082000000000001),
#  'Kajaani': (28.154, 64.474999999999994),
#  'Sao Felix do Xingu': (-51.921000000000006, -6.4029999999999996),
#  'Karlovy Vary': (13.524000000000001, 50.338000000000001),
#  'Dongloe': (-7.9020000000000001, 55.073),
#  'Hailar': (120.375, 49.341000000000001),
#  'Catarman': (125.059, 12.837),
#  'Munich': (12.31, 48.588999999999999),
#  'Harlingen': (-97.423999999999992, 26.379999999999999),
#  'Parauapebas': (-49.340000000000003, -5.5300000000000002),
#  'San Jose Del Guaviare': (-72.399000000000001, 2.9660000000000002),
#  'Campo Grande': (-54.454999999999998, -20.114999999999998),
#  'Parsabad': (48.468999999999994, 40.006),
#  'Sleetmute': (-156.61000000000001, 62.167000000000002),
#  'Valera': (-70.307000000000002, 9.5670000000000002),
#  'Makhachkala': (48.086999999999996, 43.361000000000004),
#  'Rhinelander': (-89.113, 46.052),
#  'Bettles': (-151.21600000000001, 67.522999999999996),
#  'Dangriga': (-87.694999999999993, 17.611000000000001),
#  'Dhangarhi': (80.968999999999994, 29.254999999999999),
#  'Mahe': (55.869, -4.4580000000000002),
#  'Managua': (-85.61399999999999, 12.234999999999999),
#  'Dryden': (-92.573999999999998, 50.386000000000003),
#  'Charlottesville VA': (-78.088999999999999, 38.231000000000002),
#  'Magadan': (151.19999999999999, 60.518000000000001),
#  'Westerland': (8.5670000000000002, 55.521999999999998),
#  'Schefferville': (-66.676000000000002, 55.341999999999999),
#  'Humberside': (0.081000000000000003, 53.957000000000001),
#  'Hoedspruit': (31.081, -23.948),
#  'Changuinola': (-82.194999999999993, 9.7639999999999993),
#  'Kalamazoo': (-85.253999999999991, 42.391000000000005),
#  'Nepalgunj': (82.111000000000004, 28.171999999999997),
#  'Islay': (-5.7620000000000005, 56.136000000000003),
#  'Elko': (-115.654, 41.373999999999995),
#  'Ouargla': (5.6870000000000003, 32.527999999999999),
#  'Eastmain River': (-78.204999999999998, 52.376999999999995),
#  'Sand Point': (-160.20500000000001, 55.524999999999999),
#  'Upington': (21.433000000000003, -27.999000000000002),
#  'Nicoya': (-85.754999999999995, 10.592000000000001),
#  'Hami': (94.114999999999995, 43.402000000000001),
#  'Zhengzhou': (114.40100000000001, 34.866),
#  'San Julian': (-68.031000000000006, -31.285999999999998),
#  'South Caicos': (-71.215000000000003, 21.859000000000002),
#  'Dubrovnik': (18.446999999999999, 42.935000000000002),
#  'Puerto Princesa': (119.264, 10.236000000000001),
#  'Tirana': (20.199999999999999, 41.691000000000003),
#  'Perth': (116.611, -31.901),
#  'Arctic Village': (-145.29900000000001, 68.191000000000003),
#  'Kamishly': (41.318000000000005, 37.033999999999999),
#  'Rio Verde': (-50.863999999999997, -17.651),
#  'Erzincan': (39.878, 40.183),
#  'Ronchi De Legionari': (13.787000000000001, 46.378999999999998),
#  'Niagara Falls': (-78.911000000000001, 43.178000000000004),
#  'Delhi': (77.171000000000006, 28.944000000000003),
#  'Lonorore': (168.28599999999997, -15.776),
#  'Baotou': (110.661, 40.933),
#  'Zhob': (69.771999999999991, 31.596999999999998),
#  'Maracaibo': (-71.546999999999997, 10.93),
#  'Nanaimo': (-123.78399999999999, 49.086999999999996),
#  'Nandi': (177.738, -17.593),
#  'Charlieville': (146.43700000000001, -26.023000000000003),
#  'Al-Ula': (38.513000000000005, 27.061),
#  'Chimoio': (33.713999999999999, -18.585999999999999),
#  'Wewak': (144.11500000000001, -3.3069999999999999),
#  'Norfolk': (-75.668999999999997, 37.491),
#  'Beckley': (-80.540999999999997, 38.311999999999998),
#  'Klagenfurt': (14.562000000000001, 47.07),
#  'Igloolik': (-81.694000000000003, 69.606999999999999),
#  'Augusta': (-69.662999999999997, 44.533999999999999),
#  'Takotna': (-155.47200000000001, 63.619),
#  'Rome': (12.417, 42.340000000000003),
#  'Norsup': (167.66800000000001, -15.467000000000001),
#  'Nadzab': (147.21000000000001, -6.2839999999999998),
#  'Burgos': (-3.3680000000000003, 42.596000000000004),
#  'Malatya': (38.150999999999996, 38.725000000000001),
#  'Cuiaba': (-55.527999999999999, -15.422000000000001),
#  'Sevilla': (-5.8220000000000001, 37.695999999999998),
#  'Yazd': (54.460000000000001, 32.508000000000003),
#  'Agartala': (91.400000000000006, 24.478000000000002),
#  'Funafuti': (179.327, -8.2089999999999996),
#  'Alexandroupolis': (26.593000000000004, 41.426000000000002),
#  'Tiaret': (1.7709999999999999, 35.568000000000005),
#  'Pickle Lake': (-89.691000000000003, 51.743000000000002),
#  'Santo Angelo': (-53.616000000000007, -27.803000000000001),
#  'Abadan': (48.380000000000003, 30.618000000000002),
#  'Turaif': (39.218000000000004, 32.154000000000003),
#  'Maroantsetra': (50.146999999999998, -15.062000000000001),
#  'Ballina Byron Bay': (153.93700000000001, -28.724),
#  'Manizales': (-75.108000000000004, 5.0489999999999995),
#  'Kalispell': (-113.76000000000001, 48.516999999999996),
#  'Changde': (112.066, 29.530999999999999),
#  'Chuuk': (152.405, 7.7690000000000001),
#  'Barter Island': (-143.304, 70.222999999999999),
#  'Guadalajara': (-102.852, 20.869),
#  'Kone': (165.39599999999999, -20.422999999999998),
#  'Bermuda': (-64.465000000000003, 32.606000000000002),
#  'Split': (16.495999999999999, 43.898000000000003),
#  'Laredo': (-99.102999999999994, 27.905999999999999),
#  'Visalia': (-118.988, 36.530999999999999),
#  'Jos': (9.4480000000000004, 10.066000000000001),
#  'Augsburg': (11.552, 48.707999999999998),
#  'Galcaio': (47.756999999999998, 7.3010000000000002),
#  'Constanta': (28.813000000000002, 44.603000000000002),
#  'Williams Harbour': (-55.641999999999996, 52.943999999999996),
#  'Campos': (-40.836999999999996, -21.498000000000001),
#  'False Pass': (-163.018, 55.411999999999999),
#  'Omsk': (73.516999999999996, 55.611000000000004),
#  'Basco': (122.633, 20.751999999999999),
#  'Khabarovsk': (135.31299999999999, 48.880000000000003),
#  'Ukhta': (53.803999999999995, 63.567),
#  'Lucknow': (81.481999999999999, 27.266999999999999),
#  'Chapeco': (-52.428000000000004, -26.558000000000003),
#  'Manston': (1.5759999999999998, 51.57),
#  'Ondangwa': (16.587, -17.797000000000001),
#  'Noorvik': (-160.37100000000001, 67.361999999999995),
#  'Aizwal': (93.337000000000003, 24.244),
#  'Boulder City': (-114.19, 35.941000000000003),
#  'Peshawar': (71.856999999999999, 34.655999999999999),
#  'Ibadan': (4.6299999999999999, 7.6040000000000001),
#  'Baku': (50.076999999999998, 40.779000000000003),
#  'Rio De Janeiro': (-42.740000000000002, -22.681999999999999),
#  'North Bay': (-79.037999999999997, 46.606000000000002),
#  'Godthaab': (-51.463999999999999, 64.317999999999998),
#  'Amberley': (142.76499999999999, -10.919),
#  'Phaplu': (87.0, 27.861000000000001),
#  'Huntington': (-82.263999999999996, 38.610999999999997),
#  'Erie': (-79.628, 42.136000000000003),
#  'Pangnirtung': (-65.522999999999996, 66.241),
#  'Longview': (-94.519999999999996, 32.640000000000001),
#  'Adelaide': (138.88399999999999, -34.908999999999999),
#  'Sanford': (-80.730000000000004, 29.295999999999999),
#  'Ontario': (-117.336, 34.093000000000004),
#  'Thompson': (-97.774000000000001, 56.335000000000001),
#  ...}

# %%
#visualize all the world airport cities
plt.figure(figsize = (12,6))
nx.draw(Flights,pos=CityPos,with_labels=False,arrows=False,node_size=15)

# %%
#now read the links
links = pd.read_csv( 'https://serv.cusp.nyu.edu/files/ADS-2015/NetworkAnalysis/lab1/citiesToCities.csv' , index_col=None )
links.head()
# Out:
#    departure city  long. departure (decimal)  lat. departure (decimal)  \
# 0       Sao Paulo                    -46.116                   -23.054
# 1  Rio De Janeiro                    -42.740                   -22.682
# 2         Beijing                    116.974                    40.133
# 3    Johannesburg                     28.410                   -25.566
# 4        Honolulu                   -157.871                    21.531
#
#   departure country    arrival city  long. departure (decimal).1  \
# 0            Brazil  Rio De Janeiro                      -42.740
# 1            Brazil       Sao Paulo                      -46.116
# 2             China        Shanghai                      122.342
# 3      South Africa       Cape Town                       19.002
# 4     United States           Tokyo                      140.643
#
#    lat. departure (decimal).1 arrival country  number of routes  distance
# 0                     -22.682          Brazil                18       348
# 1                     -23.054          Brazil                18       348
# 2                      31.238           China                18      1100
# 3                     -33.942    South Africa                16      1299
# 4                      36.274           Japan                16      6103

# %%
#create list of edges as tuples
EN=len(links.index)
edgelist=[0]*EN
for j in range(0,EN):
    edgelist[j]=(links['departure city'][j],links['arrival city'][j])
edgelist
# Out:
# [('Sao Paulo', 'Rio De Janeiro'),
#  ('Rio De Janeiro', 'Sao Paulo'),
#  ('Beijing', 'Shanghai'),
#  ('Johannesburg', 'Cape Town'),
#  ('Honolulu', 'Tokyo'),
#  ('Tokyo', 'Honolulu'),
#  ('Tokyo', 'Seoul'),
#  ('Seoul', 'Tokyo'),
#  ('Tokyo', 'Los Angeles'),
#  ('Los Angeles', 'Tokyo'),
#  ('Shanghai', 'Beijing'),
#  ('Hong Kong', 'Bangkok'),
#  ('Bangkok', 'Hong Kong'),
#  ('Taipei', 'Shanghai'),
#  ('Shanghai', 'Taipei'),
#  ('Cape Town', 'Johannesburg'),
#  ('Kigali', 'Entebbe'),
#  ('Shanghai', 'Hong Kong'),
#  ('Hong Kong', 'Shanghai'),
#  ('Muscat', 'Abu Dhabi'),
#  ('New York', 'London'),
#  ('Abu Dhabi', 'Muscat'),
#  ('Shenzhen', 'Shanghai'),
#  ('Shanghai', 'Shenzhen'),
#  ('Taipei', 'Tokyo'),
#  ('Tokyo', 'Taipei'),
#  ('Sao Paulo', 'Belo Horizonte'),
#  ('New York', 'Washington'),
#  ('Washington', 'New York'),
#  ('Qingdao', 'Shanghai'),
#  ('Shanghai', 'Qingdao'),
#  ('Shanghai', 'Chongqing'),
#  ('Chongqing', 'Shanghai'),
#  ('Singapore', 'Jakarta'),
#  ('Jakarta', 'Singapore'),
#  ('Sydney', 'Melbourne'),
#  ('Beijing', 'Tokyo'),
#  ('Tokyo', 'Beijing'),
#  ('London', 'Geneva'),
#  ('Geneva', 'London'),
#  ('Sao Paulo', 'Buenos Aires'),
#  ('Buenos Aires', 'Sao Paulo'),
#  ('Singapore', 'Tokyo'),
#  ('Tokyo', 'Singapore'),
#  ('Chicago', 'New York'),
#  ('New York', 'Chicago'),
#  ('Sao Paulo', 'Brasilia'),
#  ('Bahrain', 'Doha'),
#  ('London', 'Frankfurt'),
#  ("Xi'an", 'Shanghai'),
#  ('Shanghai', "Xi'an"),
#  ('Moscow', 'St. Petersburg'),
#  ('Shanghai', 'Chengdu'),
#  ('Chengdu', 'Shanghai'),
#  ('Quito', 'Guayaquil'),
#  ('Belo Horizonte', 'Sao Paulo'),
#  ('Brasilia', 'Sao Paulo'),
#  ('Tenerife', 'London'),
#  ('London', 'Tenerife'),
#  ('Seoul', 'Shanghai'),
#  ('Tokyo', 'Hong Kong'),
#  ('Hong Kong', 'Tokyo'),
#  ('Shanghai', 'Tokyo'),
#  ('Tokyo', 'Shanghai'),
#  ('London', 'Belfast'),
#  ('Belfast', 'London'),
#  ('Malaga', 'London'),
#  ('London', 'Stockholm'),
#  ('Stockholm', 'London'),
#  ('Auckland', 'Sydney'),
#  ('Madrid', 'London'),
#  ('London', 'Madrid'),
#  ('Moscow', 'Krasnodar'),
#  ('London', 'Edinburgh'),
#  ('London', 'Amsterdam'),
#  ('Krasnodar', 'Moscow'),
#  ('Edinburgh', 'London'),
#  ('Jakarta', 'Kuala Lumpur'),
#  ('Amsterdam', 'London'),
#  ('Kigali', 'Nairobi'),
#  ('Zurich', 'London'),
#  ('London', 'Zurich'),
#  ('Frankfurt', 'London'),
#  ('Chicago', 'Washington'),
#  ('Chicago', 'Paris'),
#  ('London', 'New York'),
#  ('Los Angeles', 'San Francisco'),
#  ('Los Angeles', 'New York'),
#  ('Doha', 'Bahrain'),
#  ('Paris', 'Chicago'),
#  ('Chicago', 'London'),
#  ('London', 'Chicago'),
#  ('London', 'Los Angeles'),
#  ('Los Angeles', 'London'),
#  ('Sanya', 'Shanghai'),
#  ('Shanghai', 'Kunming'),
#  ('Shanghai', 'Guangzhou'),
#  ('Shanghai', 'Sanya'),
#  ('Shanghai', 'Macau'),
#  ('Macau', 'Shanghai'),
#  ('Kunming', 'Shanghai'),
#  ('Guangzhou', 'Shanghai'),
#  ('Osaka', 'Tokyo'),
#  ('Tokyo', 'Osaka'),
#  ('Osaka', 'Seoul'),
#  ('Seoul', 'Bangkok'),
#  ('Seoul', 'Osaka'),
#  ('Bangkok', 'Seoul'),
#  ('St. Petersburg', 'Moscow'),
#  ('Singapore', 'Kuala Lumpur'),
#  ('Singapore', 'Hong Kong'),
#  ('Kuala Lumpur', 'Singapore'),
#  ('Hong Kong', 'Singapore'),
#  ('Shanghai', 'Seoul'),
#  ('Tokyo', 'Bangkok'),
#  ('Melbourne', 'Sydney'),
#  ('Bangkok', 'Tokyo'),
#  ('Guangzhou', 'Bangkok'),
#  ('Bangkok', 'Guangzhou'),
#  ('Tokyo', 'Sapporo'),
#  ('Sapporo', 'Tokyo'),
#  ('London', 'Aberdeen'),
#  ('London', 'Barcelona'),
#  ('London', 'Malaga'),
#  ('Barcelona', 'London'),
#  ('Aberdeen', 'London'),
#  ('Sydney', 'Auckland'),
#  ('Kuala Lumpur', 'Bangkok'),
#  ('Bangkok', 'Kuala Lumpur'),
#  ('London', 'Dublin'),
#  ('Kuala Lumpur', 'Jakarta'),
#  ('Rio De Janeiro', 'Belo Horizonte'),
#  ('Belo Horizonte', 'Rio De Janeiro'),
#  ('Bujumbura', 'Nairobi'),
#  ('Munich', 'London'),
#  ('London', 'Munich'),
#  ('Calgary', 'London'),
#  ('Sydney', 'Los Angeles'),
#  ('San Francisco', 'Los Angeles'),
#  ('Paris', 'Newark'),
#  ('Chicago', 'Los Angeles'),
#  ('Minneapolis', 'Chicago'),
#  ('London', 'Calgary'),
#  ('London', 'Newark'),
#  ('Los Angeles', 'Sydney'),
#  ('Las Vegas', 'Los Angeles'),
#  ('Honolulu', 'Los Angeles'),
#  ('Newark', 'Paris'),
#  ('Newark', 'London'),
#  ('Washington', 'Chicago'),
#  ('Curitiba', 'Sao Paulo'),
#  ('Auckland', 'Melbourne'),
#  ('San Francisco', 'London'),
#  ('London', 'San Francisco'),
#  ('Nanning', 'Shanghai'),
#  ('Delhi', 'Calcutta'),
#  ('Calcutta', 'Delhi'),
#  ('Urumqi', "Xi'an"),
#  ('Singapore', 'Bangkok'),
#  ('Bangkok', 'Singapore'),
#  ('Ouagadougou', 'Cotonou'),
#  ('Cotonou', 'Ouagadougou'),
#  ('Singapore', 'Denpasar'),
#  ('Denpasar', 'Singapore'),
#  ('Sao Paulo', 'Curitiba'),
#  ('London', 'Las Palmas'),
#  ('London', 'Alicante'),
#  ('Alicante', 'London'),
#  ('Las Palmas', 'London'),
#  ('Istanbul', 'Tehran'),
#  ('Tehran', 'Istanbul'),
#  ('Sao Paulo', 'Porto Alegre'),
#  ('Denver', 'Washington'),
#  ('Washington', 'Denver'),
#  ("Xi'an", 'Hangzhou'),
#  ('Beijing', 'Urumqi'),
#  ('Beijing', 'Seoul'),
#  ('Beijing', 'Guangzhou'),
#  ('Seoul', 'Beijing'),
#  ('Sharm El Sheikh', 'London'),
#  ('London', 'Sharm El Sheikh'),
#  ('Okinawa', 'Tokyo'),
#  ('Singapore', 'Brisbane'),
#  ('London', 'Manchester'),
#  ('London', 'Copenhagen'),
#  ('Copenhagen', 'London'),
#  ('Brisbane', 'Singapore'),
#  ('Washington', 'Boston'),
#  ('Boston', 'Washington'),
#  ('Portland', 'Chicago'),
#  ('San Francisco', 'Seoul'),
#  ('Seoul', 'San Francisco'),
#  ('Kuwait', 'Bahrain'),
#  ('Dublin', 'London'),
#  ('Bahrain', 'Kuwait'),
#  ('Vitoria', 'Rio De Janeiro'),
#  ('Montreal', 'Toronto'),
#  ('Toronto', 'Montreal'),
#  ('Tenerife', 'Gran Canaria'),
#  ('Palma de Mallorca', 'Barcelona'),
#  ('Gran Canaria', 'Tenerife'),
#  ('Barcelona', 'Palma de Mallorca'),
#  ('Toronto', 'London'),
#  ('Vancouver', 'London'),
#  ('St. Louis', 'Chicago'),
#  ('San Jose', 'Los Angeles'),
#  ('San Francisco', 'Seattle'),
#  ('San Francisco', 'Chicago'),
#  ('San Francisco', 'New York'),
#  ('Chicago', 'St. Louis'),
#  ('Chicago', 'Minneapolis'),
#  ('Chicago', 'Detroit'),
#  ('Chicago', 'Boston'),
#  ('Mexico City', 'Los Angeles'),
#  ('Melbourne', 'Auckland'),
#  ('London', 'Toronto'),
#  ('London', 'Vancouver'),
#  ('London', 'Boston'),
#  ('Los Angeles', 'San Jose'),
#  ('Los Angeles', 'Chicago'),
#  ('Los Angeles', 'Mexico City'),
#  ('Los Angeles', 'Honolulu'),
#  ('New York', 'San Francisco'),
#  ('New York', 'Los Angeles'),
#  ('Detroit', 'Chicago'),
#  ('Boston', 'Chicago'),
#  ('Boston', 'London'),
#  ('London', 'Larnaca'),
#  ('Larnaca', 'London'),
#  ('San Francisco', 'Hong Kong'),
#  ('London', 'Washington'),
#  ('Washington', 'London'),
#  ('Hong Kong', 'San Francisco'),
#  ('Douala', 'Bangui'),
#  ('Bangui', 'Douala'),
#  ('Xiamen', 'Shanghai'),
#  ('Tianjin', 'Shanghai'),
#  ('Shenyang', 'Shanghai'),
#  ('Shanghai', 'Tianjin'),
#  ('Shanghai', 'Changcha'),
#  ('Shanghai', 'Xiamen'),
#  ('Shanghai', 'Shenyang'),
#  ('Shanghai', 'Nanning'),
#  ('Guiyang', 'Shanghai'),
#  ('Ufa', 'Moscow'),
#  ('Moscow', 'Kiev'),
#  ('Kiev', 'Moscow'),
#  ('Seoul', 'Cheju'),
#  ('Cheju', 'Seoul'),
#  ('Delhi', 'Bombay'),
#  ('Delhi', 'Bangalore'),
#  ('Bombay', 'Delhi'),
#  ('Bombay', 'Ahmedabad'),
#  ('Bangalore', 'Delhi'),
#  ("Xi'an", 'Urumqi'),
#  ('Wuhan', 'Chongqing'),
#  ('Beijing', 'Chengdu'),
#  ('Kunming', 'Chengdu'),
#  ('Chengdu', 'Beijing'),
#  ('Chengdu', 'Kunming'),
#  ('Chongqing', 'Wuhan'),
#  ('Chongqing', 'Guangzhou'),
#  ('Guangzhou', 'Chongqing'),
#  ('Sapporo', 'Osaka'),
#  ('Dar Es Salaam', 'Nairobi'),
#  ('Sao Paulo', 'Salvador'),
#  ('Sao Paulo', 'Florianopolis'),
#  ('Cuiaba', 'Sao Paulo'),
#  ('Tenerife', 'Manchester'),
#  ('Manchester', 'Tenerife'),
#  ('London', 'Gran Canaria'),
#  ('Gran Canaria', 'London'),
#  ('Ho Chi Minh City', 'Bangkok'),
#  ('Bangkok', 'Ho Chi Minh City'),
#  ('Okinawa', 'Osaka'),
#  ('Osaka', 'Okinawa'),
#  ('Dubai', 'Muscat'),
#  ('Monrovia', 'Accra'),
#  ('Porto Alegre', 'Sao Paulo'),
#  ('Accra', 'Monrovia'),
#  ('Sydney', 'Christchurch'),
#  ('Christchurch', 'Sydney'),
#  ('Shanghai', 'Wuhan'),
#  ('Kahului', 'Kona'),
#  ('Washington', 'Charleston'),
#  ('Washington', 'Atlanta'),
#  ('Honolulu', 'Molokai'),
#  ('Atlanta', 'Washington'),
#  ('Xiamen', 'Beijing'),
#  ('Xiamen', 'Hefei'),
#  ('Urumqi', 'Beijing'),
#  ('Qingdao', 'Harbin'),
#  ('Shanghai', 'Nanchang'),
#  ('Beijing', 'Xiamen'),
#  ('Beijing', 'Lanzhou'),
#  ('Beijing', 'Hangzhou'),
#  ('Beijing', 'Dalian'),
#  ('Beijing', 'Changcha'),
#  ('Beijing', 'Changchun'),
#  ('Lanzhou', 'Beijing'),
#  ('Kunming', 'Hangzhou'),
#  ('Nanchang', 'Shanghai'),
#  ('Hong Kong', 'Hangzhou'),
#  ('Hangzhou', "Xi'an"),
#  ('Hangzhou', 'Beijing'),
#  ('Hangzhou', 'Hong Kong'),
#  ('Hangzhou', 'Guangzhou'),
#  ('Hefei', 'Xiamen'),
#  ('Dalian', 'Beijing'),
#  ('Changcha', 'Beijing'),
#  ('Changchun', 'Beijing'),
#  ('Guangzhou', 'Beijing'),
#  ('Guangzhou', 'Hangzhou'),
#  ('Busan', 'Seoul'),
#  ('Seoul', 'Busan'),
#  ('Haikou', 'Changcha'),
#  ('Changcha', 'Haikou'),
#  ('Malta', 'London'),
#  ('London', 'Malta'),
#  ('Kilimanjaro', 'Mombasa'),
#  ('Entebbe', 'Kigali'),
#  ('Tokyo', 'Okinawa'),
#  ('Sydney', 'Bangkok'),
#  ('Nice', 'London'),
#  ('Manchester', 'London'),
#  ('Lisbon', 'London'),
#  ('London', 'Lisbon'),
#  ('London', 'Dubai'),
#  ('London', 'Nice'),
#  ('London', 'Glasgow'),
#  ('London', 'Faro'),
#  ('Johannesburg', 'Durban'),
#  ('Glasgow', 'London'),
#  ('Faro', 'London'),
#  ('Dubai', 'London'),
#  ('Durban', 'Johannesburg'),
#  ('Bangkok', 'Sydney'),
#  ('Washington', 'Orlando'),
#  ('Tenerife', 'Madrid'),
#  ('Moscow', 'Khabarovsk'),
#  ('Madrid', 'Tenerife'),
#  ('Khabarovsk', 'Moscow'),
#  ('Rome', 'London'),
#  ('Portland', 'New York'),
#  ('Chicago', 'Portland'),
#  ('New York', 'Portland'),
#  ('Auckland', 'Brisbane'),
#  ('Madrid', 'Lisbon'),
#  ('Madrid', 'Amsterdam'),
#  ('Lisbon', 'Madrid'),
#  ('Sverdlovsk', 'Moscow'),
#  ('Moscow', 'Sverdlovsk'),
#  ('Moscow', 'Novosibirsk'),
#  ('Moscow', 'Omsk'),
#  ('Moscow', 'Krasnoyarsk'),
#  ('Novosibirsk', 'Moscow'),
#  ('Omsk', 'Moscow'),
#  ('Madrid', 'Paris'),
#  ('Krasnoyarsk', 'Moscow'),
#  ('New York', 'Frankfurt'),
#  ('Frankfurt', 'New York'),
#  ('Paris', 'Madrid'),
#  ('Sochi', 'Moscow'),
#  ('Rio De Janeiro', 'Porto Alegre'),
#  ('Montreal', 'Paris'),
#  ('Santiago', 'Buenos Aires'),
#  ('Luanda', 'Kinshasa'),
#  ('Kinshasa', 'Douala'),
#  ('Kinshasa', 'Brussels'),
#  ('Buenos Aires', 'Santiago'),
#  ('Douala', 'Kinshasa'),
#  ('Conakry', 'Banjul'),
#  ('Paris', 'Montreal'),
#  ('Brussels', 'Luanda'),
#  ('Brussels', 'Kigali'),
#  ('Banjul', 'Conakry'),
#  ('Barcelona', 'Ibiza'),
#  ('Abidjan', 'Lome'),
#  ('Berlin', 'London'),
#  ('Palma de Mallorca', 'Madrid'),
#  ('Paris', 'London'),
#  ('London', 'Berlin'),
#  ('London', 'Paris'),
#  ('Toronto', 'Chicago'),
#  ('Toronto', 'New York'),
#  ('Vancouver', 'Los Angeles'),
#  ('Montreal', 'New York'),
#  ('Taipei', 'Los Angeles'),
#  ('Salvador', 'Recife'),
#  ('Sacramento', 'Los Angeles'),
#  ('San Francisco', 'Tokyo'),
#  ('Seattle', 'San Francisco'),
#  ('Seattle', 'Los Angeles'),
#  ('Seattle', 'Denver'),
#  ('Santiago', 'Lima'),
#  ('San Diego', 'Chicago'),
#  ('Palm Springs', 'San Francisco'),
#  ('Chicago', 'Tampa'),
#  ('Chicago', 'San Francisco'),
#  ('Chicago', 'Seattle'),
#  ('Chicago', 'Orlando'),
#  ('Chicago', 'Fort Lauderdale'),
#  ('Chicago', 'Atlanta'),
#  ('Kahului', 'Los Angeles'),
#  ('Tokyo', 'New York'),
#  ('Miami', 'London'),
#  ('Orlando', 'Chicago'),
#  ('London', 'Montreal'),
#  ('London', 'Miami'),
#  ('London', 'Houston'),
#  ('London', 'Atlanta'),
#  ('Los Angeles', 'Vancouver'),
#  ('Los Angeles', 'Taipei'),
#  ('Los Angeles', 'Sacramento'),
#  ('Los Angeles', 'Seattle'),
#  ('Los Angeles', 'Kahului'),
#  ('Los Angeles', 'Las Vegas'),
#  ('Los Angeles', 'Kona'),
#  ('Los Angeles', 'Washington'),
#  ('Los Angeles', 'Guadalajara'),
#  ('Los Angeles', 'Dallas-fort Worth'),
#  ('Los Angeles', 'Denver'),
#  ('Los Angeles', 'Boston'),
#  ('Los Angeles', 'Auckland'),
#  ('Las Vegas', 'Chicago'),
#  ('New York', 'Toronto'),
#  ('New York', 'Montreal'),
#  ('New York', 'Tokyo'),
#  ('New York', 'Paris'),
#  ('Houston', 'London'),
#  ('Washington', 'Los Angeles'),
#  ('Tokyo', 'San Francisco'),
#  ('Guadalajara', 'Los Angeles'),
#  ('Frankfurt', 'Dallas-fort Worth'),
#  ('Dallas-fort Worth', 'Los Angeles'),
#  ('Dallas-fort Worth', 'Frankfurt'),
#  ('Denver', 'Seattle'),
#  ('Denver', 'Los Angeles'),
#  ('Boston', 'Los Angeles'),
#  ('Atlanta', 'Chicago'),
#  ('Atlanta', 'London'),
#  ('Port Hartcourt', 'Abuja'),
#  ('Abuja', 'Port Hartcourt'),
#  ('Shanghai', 'Guiyang'),
#  ('Shanghai', 'Guilin'),
#  ('Shanghai', 'Haikou'),
#  ('Guilin', 'Shanghai'),
#  ('Haikou', 'Shanghai'),
#  ('Changcha', 'Shanghai'),
#  ('Istanbul', 'Izmir'),
#  ('Izmir', 'Istanbul'),
#  ('Kunming', 'Changcha'),
#  ('Changcha', 'Kunming'),
#  ('Mineralnye Vody', 'Moscow'),
#  ('Moscow', 'Ufa'),
#  ('Tokyo', 'Fukuoka'),
#  ('Fukuoka', 'Tokyo'),
#  ('Kathmandu', 'Delhi'),
#  ('Jammu', 'Delhi'),
#  ('Guwahati', 'Delhi'),
#  ('Delhi', 'Kathmandu'),
#  ('Delhi', 'Jammu'),
#  ('Delhi', 'Guwahati'),
#  ('Bombay', 'Bangalore'),
#  ('Bangalore', 'Madras'),
#  ('Bangalore', 'Bombay'),
#  ('Ahmedabad', 'Bombay'),
#  ('Zanzibar', 'Dar Es Salaam'),
#  ('Nairobi', 'Dar Es Salaam'),
#  ('Moscow', 'Berlin'),
#  ('Berlin', 'Moscow'),
#  ('Jeddah', 'Dubai'),
#  ('Dubai', 'Jeddah'),
#  ("Xi'an", 'Lanzhou'),
#  ("Xi'an", 'Yinchuan'),
#  ('Urumqi', 'Kashi'),
#  ('Jinan', 'Dalian'),
#  ('Beijing', 'Chongqing'),
#  ('Lanzhou', "Xi'an"),
#  ('Kashi', 'Urumqi'),
#  ('Yinchuan', "Xi'an"),
#  ('Hangzhou', 'Chongqing'),
#  ('Chengdu', 'Changcha'),
#  ('Chengdu', 'Guangzhou'),
#  ('Changcha', 'Chengdu'),
#  ('Chongqing', 'Beijing'),
#  ('Chongqing', 'Hangzhou'),
#  ('Guangzhou', 'Chengdu'),
#  ('Taipei', 'Singapore'),
#  ('Singapore', 'Taipei'),
#  ('Singapore', 'Manila'),
#  ('Manila', 'Singapore'),
#  ('Guayaquil', 'Quito'),
#  ('Ouagadougou', 'Niamey'),
#  ('Niamey', 'Ouagadougou'),
#  ('Douala', 'Cotonou'),
#  ('Cotonou', 'Douala'),
#  ('Kazan', 'Moscow'),
#  ('Kaliningrad', 'Moscow'),
#  ('Moscow', 'Kazan'),
#  ('Osaka', 'Sapporo'),
#  ('Seoul', 'Fukuoka'),
#  ('Fukuoka', 'Seoul'),
#  ('Lisbon', 'Barcelona'),
#  ('Barcelona', 'Madrid'),
#  ('Barcelona', 'Lisbon'),
#  ('Kahului', 'Molokai'),
#  ('Molokai', 'Honolulu'),
#  ('Kona', 'Kahului'),
#  ('Salvador', 'Sao Paulo'),
#  ('Londrina', 'Sao Paulo'),
#  ('Goiania', 'Rio De Janeiro'),
#  ('Rio De Janeiro', 'Goiania'),
#  ('Rio De Janeiro', 'Curitiba'),
#  ('Rio De Janeiro', 'Brasilia'),
#  ('Florianopolis', 'Sao Paulo'),
#  ('Curitiba', 'Rio De Janeiro'),
#  ('Sao Paulo', 'Uberlandia'),
#  ('Sao Paulo', 'Londrina'),
#  ('Sao Paulo', 'Cuiaba'),
#  ('Brasilia', 'Rio De Janeiro'),
#  ('Vienna', 'Moscow'),
#  ('Moscow', 'Vienna'),
#  ('Santiago', 'Madrid'),
#  ('Manchester', 'Alicante'),
#  ('Barcelona', 'Tenerife'),
#  ('Alicante', 'Manchester'),
#  ('Kuwait', 'Dubai'),
#  ('Dubai', 'Kuwait'),
#  ('Colombo', 'Male'),
#  ('Phoenix', 'Minneapolis'),
#  ('Wellington', 'Sydney'),
#  ('Phuket', 'Bangkok'),
#  ('Chiang Mai', 'Bangkok'),
#  ('Bangkok', 'Chiang Mai'),
#  ('Moscow', 'Rostov'),
#  ('Wuhan', 'Shanghai'),
#  ('Urumqi', 'Shanghai'),
#  ('Shanghai', 'Urumqi'),
#  ('Shanghai', 'Zhengzhou'),
#  ('Zhengzhou', 'Shanghai'),
#  ('Salt Lake City', 'Denver'),
#  ('Chicago', 'Charleston'),
#  ('Chicago', 'Amsterdam'),
#  ('Minneapolis', 'Denver'),
#  ('Washington', 'Portland'),
#  ('Washington', 'Detroit'),
#  ('Freeport', 'Fort Lauderdale'),
#  ('Freetown', 'Banjul'),
#  ('Fort Lauderdale', 'Freeport'),
#  ('Detroit', 'Denver'),
#  ('Denver', 'Salt Lake City'),
#  ('Denver', 'Minneapolis'),
#  ('Denver', 'Detroit'),
#  ('Denver', 'Atlanta'),
#  ('Charleston', 'Chicago'),
#  ('Charleston', 'Washington'),
#  ('Banjul', 'Freetown'),
#  ('Amsterdam', 'Chicago'),
#  ('Accra', 'Lome'),
#  ('Houston', 'Denver'),
#  ('Houston', 'Washington'),
#  ('Washington', 'Houston'),
#  ('Surabaya', 'Singapore'),
#  ('Singapore', 'Surabaya'),
#  ('Los Angeles', 'Guatemala City'),
#  ('Guatemala City', 'Los Angeles'),
#  ('Brisbane', 'Auckland'),
#  ('Yantai', 'Shanghai'),
#  ('Xiamen', 'Shenzhen'),
#  ('Xiamen', 'Nanjing'),
#  ('Xiamen', 'Zhengzhou'),
#  ("Xi'an", 'Beijing'),
#  ("Xi'an", 'Nanjing'),
#  ("Xi'an", 'Nanchang'),
#  ("Xi'an", 'Changcha'),
#  ('Wuhan', 'Beijing'),
#  ('Wenzhou', 'Shanghai'),
#  ('Wenzhou', 'Guangzhou'),
#  ('Qingdao', 'Guangzhou'),
#  ('Shenzhen', 'Hangzhou'),
#  ('Sanya', 'Hangzhou'),
#  ('Sanya', 'Zhengzhou'),
#  ('Shanghai', 'Yantai'),
#  ('Shanghai', 'Huhhot'),
#  ('San Francisco', 'Denver'),
#  ('Shanghai', 'Wenzhou'),
#  ('Shanghai', 'Nagoya'),
#  ('Beijing', "Xi'an"),
#  ('Beijing', 'Wuhan'),
#  ('Beijing', 'Nanjing'),
#  ('Beijing', 'Yinchuan'),
#  ('Beijing', 'Harbin'),
#  ('Beijing', 'Hong Kong'),
#  ('Tokyo', 'Guangzhou'),
#  ('Nanjing', 'Xiamen'),
#  ('Nanjing', "Xi'an"),
#  ('Nanjing', 'Beijing'),
#  ('Nanjing', 'Haikou'),
#  ('Nanjing', 'Guangzhou'),
#  ('Nagoya', 'Shanghai'),
#  ('Nanchang', "Xi'an"),
#  ('Yinchuan', 'Beijing'),
#  ('Harbin', 'Qingdao'),
#  ('Harbin', 'Beijing'),
#  ('Harbin', 'Hangzhou'),
#  ('Harbin', 'Dalian'),
#  ('Hong Kong', 'Beijing'),
#  ('Hangzhou', 'Shenzhen'),
#  ('Hangzhou', 'Sanya'),
#  ('Hangzhou', 'Kunming'),
#  ('Hangzhou', 'Harbin'),
#  ('Huhhot', 'Shanghai'),
#  ('Haikou', 'Nanjing'),
#  ('Dalian', 'Harbin'),
#  ('Denver', 'San Francisco'),
#  ('Changcha', "Xi'an"),
#  ('Zhengzhou', 'Xiamen'),
#  ('Zhengzhou', 'Sanya'),
#  ('Guangzhou', 'Wenzhou'),
#  ('Guangzhou', 'Qingdao'),
#  ('Guangzhou', 'Tokyo'),
#  ('Guangzhou', 'Nanjing'),
#  ('Taipei', 'Seoul'),
#  ('Seoul', 'Taipei'),
#  ('Tianjin', 'Hangzhou'),
#  ('Sanya', 'Changcha'),
#  ('Nanjing', 'Changcha'),
#  ('Hangzhou', 'Tianjin'),
#  ('Hangzhou', 'Changcha'),
#  ('Changcha', 'Sanya'),
#  ('Changcha', 'Nanjing'),
#  ('Changcha', 'Hangzhou'),
#  ('Entebbe', 'Addis Ababa'),
#  ('Addis Ababa', 'Entebbe'),
#  ('Singapore', 'Melbourne'),
#  ('Singapore', 'Frankfurt'),
#  ('Melbourne', 'Singapore'),
#  ('London', 'Budapest'),
#  ('Frankfurt', 'Singapore'),
#  ('Durban', 'Cape Town'),
#  ('Cape Town', 'Durban'),
#  ('Budapest', 'London'),
#  ('San Francisco', 'Boston'),
#  ('Orlando', 'Washington'),
#  ('New York', 'Denver'),
#  ('Denver', 'New York'),
#  ('Denver', 'Boston'),
#  ('Boston', 'Denver'),
#  ('Vladivostok', 'Moscow'),
#  ('Tenerife', 'Barcelona'),
#  ('Moscow', 'Vladivostok'),
#  ('Milano', 'Rome'),
#  ('Madrid', 'Gran Canaria'),
#  ('Gran Canaria', 'Barcelona'),
#  ('Rome', 'Milano'),
#  ('Barcelona', 'Gran Canaria'),
#  ('Rio De Janeiro', 'Buenos Aires'),
#  ('Buenos Aires', 'Rio De Janeiro'),
#  ('Amsterdam', 'Madrid'),
#  ('Penang', 'Kuala Lumpur'),
#  ('Moscow', 'Samara'),
#  ('Moscow', 'Irkutsk'),
#  ('Moscow', 'Sochi'),
#  ('Lisbon', 'Paris'),
#  ('Milan', 'Paris'),
#  ('Irkutsk', 'Moscow'),
#  ('Houston', 'Paris'),
#  ('Washington', 'Paris'),
#  ('Rome', 'Paris'),
#  ('Paris', 'Lisbon'),
#  ('Paris', 'Milan'),
#  ('Paris', 'Houston'),
#  ('Paris', 'Washington'),
#  ('Paris', 'Rome'),
#  ('Paris', 'Barcelona'),
#  ('Barcelona', 'Paris'),
#  ('Campinas', 'Belo Horizonte'),
#  ('Salvador', 'Rio De Janeiro'),
#  ('Porto Alegre', 'Rio De Janeiro'),
#  ('Rio De Janeiro', 'Vitoria'),
#  ('Belo Horizonte', 'Campinas'),
#  ('Belo Horizonte', 'Porto Seguro'),
#  ('Porto Seguro', 'Sao Paulo'),
#  ('Vancouver', 'Calgary'),
#  ('Monrovia', 'Abidjan'),
#  ('Ouagadougou', 'Brussels'),
#  ('Nairobi', 'Brussels'),
#  ('Lome', 'Brussels'),
#  ('Jeddah', 'Riyadh'),
#  ('Ibiza', 'Barcelona'),
#  ('Entebbe', 'Brussels'),
#  ('Douala', 'Brussels'),
#  ('Brussels', 'Monrovia'),
#  ('Brussels', 'Ouagadougou'),
#  ('Brussels', 'Douala'),
#  ('Brussels', 'Bujumbura'),
#  ('Brussels', 'Banjul'),
#  ('Brussels', 'Abidjan'),
#  ('Banjul', 'Brussels'),
#  ('Abidjan', 'Brussels'),
#  ('Valencia', 'Palma de Mallorca'),
#  ('Vienna', 'Barcelona'),
#  ('Salzburg', 'London'),
#  ('London', 'Duesseldorf'),
#  ('Palma de Mallorca', 'Valencia'),
#  ('Munich', 'Istanbul'),
#  ('Madrid', 'Palma de Mallorca'),
#  ('London', 'Hamburg'),
#  ('London', 'Basel-Mulhouse-Freiburg'),
#  ('London', 'Salzburg'),
#  ('Hamburg', 'London'),
#  ('Frankfurt', 'Vienna'),
#  ('Duesseldorf', 'London'),
#  ('Basel-Mulhouse-Freiburg', 'London'),
#  ('Barcelona', 'Vienna'),
#  ('Montreal', 'London'),
#  ('Taipei', 'San Francisco'),
#  ('Tampa', 'Chicago'),
#  ('Santa Ana', 'Chicago'),
#  ('Salt Lake City', 'Chicago'),
#  ('Salt Lake City', 'Los Angeles'),
#  ('Springfield', 'Chicago'),
#  ('San Francisco', 'Taipei'),
#  ('San Francisco', 'Palm Springs'),
#  ('San Francisco', 'Portland'),
#  ('Seattle', 'Chicago'),
#  ('San Diego', 'Los Angeles'),
#  ('Fort Myers', 'Chicago'),
#  ('Raleigh-durham', 'New York'),
#  ('Phoenix', 'Portland'),
#  ('Phoenix', 'Los Angeles'),
#  ('Philadelphia', 'Chicago'),
#  ('Portland', 'San Francisco'),
#  ('Portland', 'Phoenix'),
#  ('Portland', 'Los Angeles'),
#  ('Chicago', 'Toronto'),
#  ('Chicago', 'Springfield'),
#  ('Chicago', 'San Antonio'),
#  ('Chicago', 'San Diego'),
#  ('Chicago', 'Fort Myers'),
#  ('Chicago', 'Tokyo'),
#  ('Chicago', 'Mexico City'),
#  ('Chicago', 'Las Vegas'),
#  ('Chicago', 'Houston'),
#  ('Chicago', 'Dallas-fort Worth'),
#  ('Chicago', 'Denver'),
#  ('Tokyo', 'Chicago'),
#  ('New Orleans', 'Chicago'),
#  ('Miami', 'Paris'),
#  ('Mexico City', 'Chicago'),
#  ('Orlando', 'London'),
#  ('Orlando', 'Los Angeles'),
#  ('Orlando', 'New York'),
#  ('Madrid', 'New York'),
#  ('Lima', 'Santiago'),
#  ('Lihue', 'Los Angeles'),
#  ('London', 'Orlando'),
#  ('New York', 'Charlotte'),
#  ('London', 'Shannon'),
#  ('Los Angeles', 'San Diego'),
#  ('Los Angeles', 'Phoenix'),
#  ('Los Angeles', 'Orlando'),
#  ('Los Angeles', 'Lihue'),
#  ('Los Angeles', 'Albuquerque'),
#  ('Kona', 'Los Angeles'),
#  ('New York', 'Raleigh-durham'),
#  ('New York', 'Orlando'),
#  ('New York', 'Madrid'),
#  ('New York', 'Fort Lauderdale'),
#  ('New York', 'Boston'),
#  ('Houston', 'Chicago'),
#  ('Fort Lauderdale', 'Chicago'),
#  ('Fort Lauderdale', 'New York'),
#  ('Dallas-fort Worth', 'San Francisco'),
#  ('Dallas-fort Worth', 'Denver'),
#  ('Denver', 'Chicago'),
#  ('Denver', 'Dallas-fort Worth'),
#  ('Charlotte', 'New York'),
#  ('Paris', 'Miami'),
#  ('Paris', 'New York'),
#  ('Boston', 'New York'),
#  ('Auckland', 'Los Angeles'),
#  ('Chicago', 'Hong Kong'),
#  ('London', 'Delhi'),
#  ('London', 'Bombay'),
#  ('New York', 'Brussels'),
#  ('Hong Kong', 'Chicago'),
#  ('Delhi', 'London'),
#  ('Brussels', 'New York'),
#  ('Bombay', 'London'),
#  ('Porlamar', 'Caracas'),
#  ('Caracas', 'Porlamar'),
#  ('Zhuhai', 'Shanghai'),
#  ('Shijiazhuang', 'Shanghai'),
#  ('Shenyang', 'Hangzhou'),
#  ('Shanghai', 'Shijiazhuang'),
#  ('Shanghai', 'Fuzhou'),
#  ('Shanghai', 'Zhuhai'),
#  ('Hangzhou', 'Shenyang'),
#  ('Fuzhou', 'Shanghai'),
#  ('Shenyang', 'Zhengzhou'),
#  ('Kunming', 'Jinghong'),
#  ('Jinghong', 'Kunming'),
#  ('Zhengzhou', 'Shenyang'),
#  ('Moscow', 'Mineralnye Vody'),
#  ('Nagoya', 'Seoul'),
#  ('Seoul', 'Hong Kong'),
#  ('Hong Kong', 'Seoul'),
#  ('Seoul', 'Nagoya'),
#  ('Srinagar', 'Jammu'),
#  ('Srinagar', 'Delhi'),
#  ('Singapore', 'Bombay'),
#  ('Pune', 'Delhi'),
#  ('Patina', 'Delhi'),
#  ('Madras', 'Delhi'),
#  ('Madras', 'Bangalore'),
#  ('Lucknow', 'Delhi'),
#  ('Jammu', 'Srinagar'),
#  ('Hyderabad', 'Delhi'),
#  ('Hyderabad', 'Bombay'),
#  ('Goa', 'Bombay'),
#  ('Delhi', 'Srinagar'),
#  ('Delhi', 'Pune'),
#  ('Delhi', 'Madras'),
#  ('Delhi', 'Lucknow'),
#  ('Delhi', 'Hyderabad'),
#  ('Delhi', 'Bangkok'),
#  ('Delhi', 'Ahmedabad'),
#  ('Kochi', 'Bombay'),
#  ('Bombay', 'Singapore'),
#  ('Bombay', 'Hyderabad'),
#  ('Bombay', 'Goa'),
#  ('Bombay', 'Kochi'),
#  ('Bombay', 'Bangkok'),
#  ('Bangkok', 'Delhi'),
#  ('Bangkok', 'Bombay'),
#  ('Ahmedabad', 'Delhi'),
#  ('Montevideo', 'Buenos Aires'),
#  ('Buenos Aires', 'Montevideo'),
#  ('Vladivostok', 'Khabarovsk'),
#  ('Khabarovsk', 'Vladivostok'),
#  ('Trinidad', 'Santa Cruz'),
#  ('Seoul', 'Cebu'),
#  ('Cebu', 'Seoul'),
#  ('Nairobi', 'Mombasa'),
#  ('Dar Es Salaam', 'Zanzibar'),
#  ('Nicoya', 'San Jose'),
#  ('San Jose', 'Nicoya'),
#  ('Xining', "Xi'an"),
#  ('Xiamen', 'Kunming'),
#  ('Xiamen', 'Changcha'),
#  ("Xi'an", 'Xining'),
#  ("Xi'an", 'Chengdu'),
#  ("Xi'an", 'Chongqing'),
#  ('Wuhan', 'Nanning'),
#  ('Wuhan', 'Chengdu'),
#  ('Urumqi', 'Chengdu'),
#  ('Urumqi', 'Chongqing'),
#  ('Jinan', 'Harbin'),
#  ('Jinan', 'Chengdu'),
#  ('Shenzhen', 'Chengdu'),
#  ('Sanya', 'Chengdu'),
#  ('Nanning', 'Wuhan'),
#  ('Nanjing', 'Chongqing'),
#  ('Lhasa', 'Chongqing'),
#  ('Guiyang', 'Kunming'),
#  ('Kunming', 'Xiamen'),
#  ('Kunming', 'Guiyang'),
#  ('Kunming', 'Chongqing'),
#  ('Harbin', 'Jinan'),
#  ('Hong Kong', 'Chengdu'),
#  ('Dalian', 'Jinan'),
#  ('Chengdu', "Xi'an"),
#  ('Chengdu', 'Wuhan'),
#  ('Chengdu', 'Urumqi'),
#  ('Chengdu', 'Jinan'),
#  ('Chengdu', 'Shenzhen'),
#  ('Chengdu', 'Sanya'),
#  ('Chengdu', 'Hong Kong'),
#  ('Changcha', 'Xiamen'),
#  ('Changcha', 'Chongqing'),
#  ('Chongqing', "Xi'an"),
#  ('Chongqing', 'Urumqi'),
#  ('Chongqing', 'Nanjing'),
#  ('Chongqing', 'Lhasa'),
#  ('Chongqing', 'Kunming'),
#  ('Chongqing', 'Changcha'),
#  ('Taipei', 'Osaka'),
#  ('Singapore', 'Ho Chi Minh City'),
#  ('Singapore', 'Perth'),
#  ('Singapore', 'Penang'),
#  ('Ho Chi Minh City', 'Singapore'),
#  ('Perth', 'Singapore'),
#  ('Penang', 'Singapore'),
#  ('Osaka', 'Taipei'),
#  ('Moscow', 'Kaliningrad'),
#  ('Moscow', 'Chelyabinsk'),
#  ('Chelyabinsk', 'Moscow'),
#  ('Sharm El Sheikh', 'Manchester'),
#  ('Manchester', 'Sharm El Sheikh'),
#  ('Moscow', 'Odessa'),
#  ('Odessa', 'Moscow'),
#  ('Paris', 'Porto'),
#  ('Porto', 'Paris'),
#  ('San Jose', 'Phoenix'),
#  ('Phoenix', 'San Jose'),
#  ('Khartoum', 'Jeddah'),
#  ('Jeddah', 'Khartoum'),
#  ('Osh', 'Moscow'),
#  ('Moscow', 'Osh'),
#  ('Douala', 'Libreville'),
#  ('Milano', 'Barcelona'),
#  ('Madrid', 'Moscow'),
#  ('Madrid', 'Barcelona'),
#  ('Moscow', 'Madrid'),
#  ('Moscow', 'Barcelona'),
#  ('Barcelona', 'Milano'),
#  ('Barcelona', 'Moscow'),
#  ('Khabarovsk', 'Magadan'),
#  ('Magadan', 'Khabarovsk'),
#  ('Barcelona', 'Amsterdam'),
#  ('Amsterdam', 'Barcelona'),
#  ('Molokai', 'Kahului'),
#  ('Lanai', 'Honolulu'),
#  ('Honolulu', 'Kahului'),
#  ('Salvador', 'Brasilia'),
#  ('Salvador', 'Aracaju'),
#  ('Sao Luis', 'Belem'),
#  ('Porto Velho', 'Cuiaba'),
#  ('Goiania', 'Cuiaba'),
#  ('Florianopolis', 'Porto Alegre'),
#  ('Campo Grande', 'Sao Paulo'),
#  ('Sao Paulo', 'Campo Grande'),
#  ('Cuiaba', 'Goiania'),
#  ('Brasilia', 'Salvador'),
#  ('Belem', 'Sao Luis'),
#  ('Belem', 'Maraba'),
#  ('Aracaju', 'Salvador'),
#  ('Tenerife', 'East Midlands'),
#  ('Sevilla', 'Barcelona'),
#  ('London', 'Grenoble'),
#  ('Santiago', 'Barcelona'),
#  ('Porto', 'Madrid'),
#  ('Madrid', 'Porto'),
#  ('London', 'Fuerteventura'),
#  ('Grenoble', 'London'),
#  ('Fuerteventura', 'London'),
#  ('East Midlands', 'Tenerife'),
#  ('Barcelona', 'Sevilla'),
#  ('Barcelona', 'Santiago'),
#  ('Barcelona', 'Malaga'),
#  ('Malaga', 'Manchester'),
#  ('Malaga', 'Barcelona'),
#  ('Taiyuan', 'Shanghai'),
#  ('Shanghai', 'Taiyuan'),
#  ('Shanghai', 'Bangkok'),
#  ('Bangkok', 'Shanghai'),
#  ('Ko Samui', 'Singapore'),
#  ('Singapore', 'Ko Samui'),
#  ('Hanoi', 'Bangkok'),
#  ('Bangkok', 'Hanoi'),
#  ('Amman', 'Abu Dhabi'),
#  ('Milano', 'Brussels'),
#  ('Brussels', 'Milano'),
#  ('Male', 'Colombo'),
#  ('Muscat', 'Dubai'),
#  ('Karachi', 'Dubai'),
#  ('Dubai', 'Karachi'),
#  ('Jeddah', 'Alexandria'),
#  ('Alexandria', 'Jeddah'),
#  ('Seattle', 'Seoul'),
#  ('Porto Alegre', 'Montevideo'),
#  ('Navegantes', 'Sao Paulo'),
#  ('Minneapolis', 'Phoenix'),
#  ('Los Angeles', 'Seoul'),
#  ('New York', 'Seoul'),
#  ('Seoul', 'Seattle'),
#  ('Seoul', 'Los Angeles'),
#  ('Seoul', 'New York'),
#  ('Goiania', 'Sao Paulo'),
#  ('Brasilia', 'Goiania'),
#  ('Atlanta', 'Denver'),
#  ('Wellington', 'Auckland'),
#  ('Sydney', 'Wellington'),
#  ('Perth', 'Denpasar'),
#  ('Melbourne', 'Wellington'),
#  ('Melbourne', 'Brisbane'),
#  ('Denpasar', 'Perth'),
#  ('Brisbane', 'Melbourne'),
#  ('Dubai', 'Colombo'),
#  ('Colombo', 'Dubai'),
#  ('Chiang Rai', 'Bangkok'),
#  ('Bangkok', 'Phuket'),
#  ('Bangkok', 'Chiang Rai'),
#  ('Rostov', 'Moscow'),
#  ('Xiamen', 'Guangzhou'),
#  ("Xi'an", 'Wuhan'),
#  ('Wuhan', "Xi'an"),
#  ('Wuhan', 'Sanya'),
#  ...]

# %%
#add edges to the network
Flights.add_edges_from(edgelist)

# %%
#visualize the network
plt.figure(figsize = (12,6))
nx.draw(Flights,pos=CityPos,with_labels=False,node_size=15,style='dotted',edge_color='green')

# %%
#most connected airport
d=Flights.degree().values()
j=np.argmax(d)
print('Most connected airport is {0} with {1} connections'.format(Flights.degree().keys()[j],d[j]))
# Out:
# Most connected airport is London with 311 connections

# %%
#least connected airport
j=np.argmin(d)
print('Least connected airport is {0} with {1} connections'.format(Flights.degree().keys()[j],d[j]))
# Out:
# Least connected airport is Bar Harbor with 1 connections

# %%
#compute network average number of connections per airport and network density
k_avg=mean(d)
dens=k_avg/(len(d)-1)
print('Average number of connections per airport is {0}; network density ={1}'.format(k_avg,dens))
# Out:
# Average number of connections per airport is 10.4738955823; network density =0.00350649333188
